# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from datetime import datetime
from vnstock import *
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from copy import deepcopy as dc
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# config
stock_target='FPT'
lookback = 5
origin_start_date= datetime(2020, 1, 2)
start_date = datetime(2023, 8, 20)
end_date = datetime(2023, 12, 25)

# %% [markdown]
# #### Util

# %%
def move_day(today): 
    if today.weekday() == 5:  # Saturday
     today += timedelta(days=2)
    elif today.weekday() == 6:  # Sunday
     today += timedelta(days=1)
    return today

def generate_date_range(start_date, end_date):
    # mapping to stock is that day exist 
    df_map = stock_historical_data(symbol=stock_target, start_date=start_date.strftime('%Y-%m-%d'),end_date=end_date.strftime('%Y-%m-%d'), resolution="1D", type="stock", beautify=True, decor=False, source='DNSE')
        
    return pd.to_datetime(df_map['time'])


def restore_df(X_scaler,y_scaler,scaler):
   
   num_features = 0
   # (number samples, number time steps, number features)
   if X_scaler.shape[1] == 1:
      num_features = X_scaler.shape[2]
   elif  X_scaler.shape[2] == 1:
      num_features = X_scaler.shape[1]  

   dummies = np.zeros((X_scaler.shape[0],num_features + 1))
   if  X_scaler.shape[1] == 1:
        # don't use timestep instead use features
       dummies[:,1:] = X_scaler.reshape((X_scaler.shape[0],X_scaler.shape[2]))
   elif X_scaler.shape[1] != 1:
       # use time steps
       dummies[:,1:] = X_scaler.reshape((X_scaler.shape[0],X_scaler.shape[1]))
   dummies[:, 0] = y_scaler.flatten()
   df = scaler.inverse_transform(dummies)
   return df

def get_predict_and_df(model, X, scaler):
    if isinstance(X, np.ndarray):
        X = torch.tensor(X).float() 
    
    with torch.no_grad():
       y_predicted = model(X.to(device)).to('cpu').numpy()
      
    y_predict = y_predicted.flatten()
    df = restore_df(X, y_predict, scaler)
    return df
   
def get_predict(model, X, scaler):
    with torch.no_grad():
      df = get_predict_and_df(model, X, scaler)
      return df[:,:1].reshape(df.shape[0])
    
def get_predict_next_day(model,scaler,shifted_df_as_np_scaler, lag=60):
    X_predict_next_day = create_X_predict_next_day(shifted_df_as_np_scaler,lag) 
    X = create_X_LSTM(X_predict_next_day)
    y_predict = get_predict(model, X, scaler)[-1:]
    return y_predict
    
def create_X_LSTM(X):
    X_flip = dc(np.flip(X, axis = 1))
    X_flip_3D = X_flip.reshape((-1, lookback, 1))
    return X_flip_3D
    
def create_X_predict_next_day(shifted_df_as_np_scaler ,lag=60):
    lag_X = shifted_df_as_np_scaler[-lag:,1:]
    latest_X = shifted_df_as_np_scaler[-1:,:lookback]
    return create_X_LSTM(np.append(lag_X,latest_X,axis=0))

    
def create_scaler_df(df):
     df_np = df.to_numpy()
     scaler = MinMaxScaler(feature_range = (0, 1))
     df_np_scaler = scaler.fit_transform(df_np)
     return df_np_scaler, scaler

def multi_scaler_df(df_list):
    df_np_scaler_list = []
    scaler_list = []
    for df in df_list:    
      df_np_scaler, scaler = create_scaler_df(df)
      df_np_scaler_list.append(df_np_scaler)
      scaler_list.append(scaler)
    return df_np_scaler_list, scaler_list

# %%
day_test_range = generate_date_range(start_date,end_date)

# %%
len(day_test_range)
# Out:
# 89

# %%
def get_list_next_day_actual_test_range():
    begin_day = (day_test_range.iloc[0] + timedelta(days=1)).strftime('%Y-%m-%d')
    stop_day = (day_test_range.iloc[-1] + timedelta(days=1)).strftime('%Y-%m-%d')
    df_raw = stock_historical_data(symbol=stock_target, start_date=begin_day,end_date=stop_day, resolution="1D", type="stock", beautify=True, decor=False, source='DNSE')
    return df_raw

# %%
df_fw_list = []
print("Get stock data from origin data 2020-01-02 to latest test day "+ end_date.strftime('%Y-%m-%d'))
df_raw = stock_historical_data(symbol=stock_target, start_date=origin_start_date.strftime('%Y-%m-%d') ,end_date=end_date.strftime('%Y-%m-%d'), resolution="1D", type="stock", beautify=True, decor=False, source='DNSE')
df_fw_gen = pd.DataFrame()
df_fw_gen[['ds','y']] = df_raw[['time','close']]
df_fw_gen['ds'] = pd.to_datetime(df_fw_gen['ds'] )

for upper_bound_date in  day_test_range:
    df_fw = df_fw_gen[ df_fw_gen['ds'] <= upper_bound_date]
    print(f"Create train set from {origin_start_date.strftime('%Y-%m-%d')} to {upper_bound_date.strftime('%Y-%m-%d')}")
    df_fw_list.append(df_fw)
# Out:
# Get stock data from origin data 2020-01-02 to latest test day 2023-12-25
# Create train set from 2020-01-02 to 2023-08-21
# Create train set from 2020-01-02 to 2023-08-22
# Create train set from 2020-01-02 to 2023-08-23
# Create train set from 2020-01-02 to 2023-08-24
# Create train set from 2020-01-02 to 2023-08-25
# Create train set from 2020-01-02 to 2023-08-28
# Create train set from 2020-01-02 to 2023-08-29
# Create train set from 2020-01-02 to 2023-08-30
# Create train set from 2020-01-02 to 2023-08-31
# Create train set from 2020-01-02 to 2023-09-05
# Create train set from 2020-01-02 to 2023-09-06
# Create train set from 2020-01-02 to 2023-09-07
# Create train set from 2020-01-02 to 2023-09-08
# Create train set from 2020-01-02 to 2023-09-11
# Create train set from 2020-01-02 to 2023-09-12
# Create train set from 2020-01-02 to 2023-09-13
# Create train set from 2020-01-02 to 2023-09-14
# Create train set from 2020-01-02 to 2023-09-15
# Create train set from 2020-01-02 to 2023-09-18
# Create train set from 2020-01-02 to 2023-09-19
# Create train set from 2020-01-02 to 2023-09-20
# Create train set from 2020-01-02 to 2023-09-21
# Create train set from 2020-01-02 to 2023-09-22
# Create train set from 2020-01-02 to 2023-09-25
# Create train set from 2020-01-02 to 2023-09-26
# Create train set from 2020-01-02 to 2023-09-27
# Create train set from 2020-01-02 to 2023-09-28
# Create train set from 2020-01-02 to 2023-09-29
# Create train set from 2020-01-02 to 2023-10-02
# Create train set from 2020-01-02 to 2023-10-03
# Create train set from 2020-01-02 to 2023-10-04
# Create train set from 2020-01-02 to 2023-10-05
# Create train set from 2020-01-02 to 2023-10-06
# Create train set from 2020-01-02 to 2023-10-09
# Create train set from 2020-01-02 to 2023-10-10
# Create train set from 2020-01-02 to 2023-10-11
# Create train set from 2020-01-02 to 2023-10-12
# Create train set from 2020-01-02 to 2023-10-13
# Create train set from 2020-01-02 to 2023-10-16
# Create train set from 2020-01-02 to 2023-10-17
# Create train set from 2020-01-02 to 2023-10-18
# Create train set from 2020-01-02 to 2023-10-19
# Create train set from 2020-01-02 to 2023-10-20
# Create train set from 2020-01-02 to 2023-10-23
# Create train set from 2020-01-02 to 2023-10-24
# Create train set from 2020-01-02 to 2023-10-25
# Create train set from 2020-01-02 to 2023-10-26
# Create train set from 2020-01-02 to 2023-10-27
# Create train set from 2020-01-02 to 2023-10-30
# Create train set from 2020-01-02 to 2023-10-31
# Create train set from 2020-01-02 to 2023-11-01
# Create train set from 2020-01-02 to 2023-11-02
# Create train set from 2020-01-02 to 2023-11-03
# Create train set from 2020-01-02 to 2023-11-06
# Create train set from 2020-01-02 to 2023-11-07
# Create train set from 2020-01-02 to 2023-11-08
# Create train set from 2020-01-02 to 2023-11-09
# Create train set from 2020-01-02 to 2023-11-10
# Create train set from 2020-01-02 to 2023-11-13
# Create train set from 2020-01-02 to 2023-11-14
# Create train set from 2020-01-02 to 2023-11-15
# Create train set from 2020-01-02 to 2023-11-16
# Create train set from 2020-01-02 to 2023-11-17
# Create train set from 2020-01-02 to 2023-11-20
# Create train set from 2020-01-02 to 2023-11-21
# Create train set from 2020-01-02 to 2023-11-22
# Create train set from 2020-01-02 to 2023-11-23
# Create train set from 2020-01-02 to 2023-11-24
# Create train set from 2020-01-02 to 2023-11-27
# Create train set from 2020-01-02 to 2023-11-28
# Create train set from 2020-01-02 to 2023-11-29
# Create train set from 2020-01-02 to 2023-11-30
# Create train set from 2020-01-02 to 2023-12-01
# Create train set from 2020-01-02 to 2023-12-04
# Create train set from 2020-01-02 to 2023-12-05
# Create train set from 2020-01-02 to 2023-12-06
# Create train set from 2020-01-02 to 2023-12-07
# Create train set from 2020-01-02 to 2023-12-08
# Create train set from 2020-01-02 to 2023-12-11
# Create train set from 2020-01-02 to 2023-12-12
# Create train set from 2020-01-02 to 2023-12-13
# Create train set from 2020-01-02 to 2023-12-14
# Create train set from 2020-01-02 to 2023-12-15
# Create train set from 2020-01-02 to 2023-12-18
# Create train set from 2020-01-02 to 2023-12-19
# Create train set from 2020-01-02 to 2023-12-20
# Create train set from 2020-01-02 to 2023-12-21
# Create train set from 2020-01-02 to 2023-12-22
# Create train set from 2020-01-02 to 2023-12-25

# %%
list_model = []
shifted_df_list = []

# %%
def prepare_dataframe_for_lstm(df, n_steps):
  df = dc(df)
  df['ds'] = pd.to_datetime(df['ds'])

  df.set_index('ds', inplace = True)

  for i in range(1, n_steps + 1):
    df[f'y(t-{i})'] = df['y'].shift(i)
  df.dropna(inplace = True)

  return df


for df_fw in df_fw_list:
   shifted_df  = prepare_dataframe_for_lstm(df_fw,lookback)
   shifted_df_list.append(shifted_df)

# %%
shifted_df_as_np_scaler_list, scaler_list = multi_scaler_df(shifted_df_list)

# %%
X_list = []
y_list = []

shifted_df_as_np_scaler_list, scaler_list = multi_scaler_df(shifted_df_list)

for shifted_df_as_np_scaler in shifted_df_as_np_scaler_list:
    X = shifted_df_as_np_scaler[:, 1:]
    y = shifted_df_as_np_scaler[:, 0:1]
    X_list.append(X)
    y_list.append(y)


X_list[0].shape, y_list[0].shape
# Out:
# ((904, 5), (904, 1))

# %%
X_list = [dc(np.flip(X, axis = 1)) for X in X_list]

X_list[0].shape
# Out:
# (904, 5)

# %%
X_train_list = X_list
y_train_list = y_list

X_train_list[0].shape, y_train_list[0].shape
# Out:
# ((904, 5), (904, 1))

# %%
X_train_list = [X_train.reshape((-1, lookback, 1)) for X_train in X_train_list]
y_train_list =  [y_train.reshape((-1, 1)) for y_train in y_train_list]

X_train_list[0].shape, y_train_list[0].shape
# Out:
# ((904, 5, 1), (904, 1))

# %%
X_train_list = [torch.tensor(X_train).float() for X_train in X_train_list]
y_train_list = [torch.tensor(y_train).float() for y_train in y_train_list]

X_train_list[0].shape, y_train_list[0].shape
# Out:
# (torch.Size([904, 5, 1]), torch.Size([904, 1]))

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset):
  def __init__(self, X, y):
    self.X = X
    self.y = y

  def __len__(self):
    return len(self.X)

  def __getitem__(self, i):
    return self.X[i], self.y[i]


train_dataset_list = [TimeSeriesDataset(X_train, y_train) for X_train, y_train in zip(X_train_list,y_train_list)]

# %%
train_dataset_list[0]

# %%
from torch.utils.data import DataLoader

batch_size = 12

train_loader_list = [DataLoader(train_dataset, batch_size = batch_size, shuffle = True) for train_dataset in train_dataset_list ]

# %%
class LSTM(nn.Module):
  def __init__(self, input_size, hidden_size, num_stacked_layers):
    super().__init__()
    self.hidden_size = hidden_size
    self.num_stacked_layers = num_stacked_layers
    self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers,
                        batch_first = True)
    self.fc = nn.Linear(hidden_size, 1)

  def forward(self, x):
    batch_size = x.size(0)
    h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
    c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
    out, _ = self.lstm(x, (h0, c0))
    out = self.fc(out[:, -1, :])
    return out



for i in range(len(train_loader_list)):
  m = LSTM(1, 4, 1) #1,4,1 19:30
  m.to(device)
  list_model.append(m)

# %%
learning_rate = 0.001
num_epochs = 20
loss_function = nn.MSELoss()

def train_one_epoch(model,train_loader,epoch):
  optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
  model.train(True)
  print(f'Epoch: {epoch + 1}')
  running_loss = 0.0

  for batch_index, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    output = model(x_batch)
    loss = loss_function(output, y_batch)
    running_loss += loss.item()

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if batch_index % 20 == 10: # print every 10 batches
        avg_loss_across_batches = running_loss / 1
        print('Batch {0}, Loss: {1:.3f}'.format(batch_index+1,
                                              avg_loss_across_batches))
        running_loss = 0.0
  print()

# %%
for model, train_loader in zip(list_model,train_loader_list):
  for epoch in range(num_epochs):
    train_one_epoch(model=model,train_loader=train_loader,epoch=epoch)
# Out:
# Epoch: 1
# Batch 11, Loss: 4.030
# Batch 31, Loss: 6.684
# Batch 51, Loss: 5.107
# Batch 71, Loss: 4.129
#
# Epoch: 2
# Batch 11, Loss: 1.559
# Batch 31, Loss: 1.950
# Batch 51, Loss: 1.501
# Batch 71, Loss: 1.226
#
# Epoch: 3
# Batch 11, Loss: 0.583
# Batch 31, Loss: 1.049
# Batch 51, Loss: 0.965
# Batch 71, Loss: 0.824
#
# Epoch: 4
# Batch 11, Loss: 0.474
# Batch 31, Loss: 0.679
# Batch 51, Loss: 0.608
# Batch 71, Loss: 0.527
#
# Epoch: 5
# Batch 11, Loss: 0.235
# Batch 31, Loss: 0.293
# Batch 51, Loss: 0.198
# Batch 71, Loss: 0.109
#
# Epoch: 6
# Batch 11, Loss: 0.034
# Batch 31, Loss: 0.027
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 7
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.013
#
# Epoch: 8
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.011
#
# Epoch: 9
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.013
#
# Epoch: 10
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.015
# Batch 71, Loss: 0.009
#
# Epoch: 11
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.011
#
# Epoch: 12
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.011
#
# Epoch: 13
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.010
#
# Epoch: 14
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.011
#
# Epoch: 15
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.012
#
# Epoch: 16
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.012
#
# Epoch: 17
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.010
#
# Epoch: 18
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 19
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.011
#
# Epoch: 1
# Batch 11, Loss: 2.615
# Batch 31, Loss: 4.443
# Batch 51, Loss: 3.635
# Batch 71, Loss: 2.769
#
# Epoch: 2
# Batch 11, Loss: 1.268
# Batch 31, Loss: 1.841
# Batch 51, Loss: 1.513
# Batch 71, Loss: 1.186
#
# Epoch: 3
# Batch 11, Loss: 0.548
# Batch 31, Loss: 0.869
# Batch 51, Loss: 0.732
# Batch 71, Loss: 0.532
#
# Epoch: 4
# Batch 11, Loss: 0.201
# Batch 31, Loss: 0.226
# Batch 51, Loss: 0.102
# Batch 71, Loss: 0.035
#
# Epoch: 5
# Batch 11, Loss: 0.011
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.019
# Batch 71, Loss: 0.015
#
# Epoch: 6
# Batch 11, Loss: 0.011
# Batch 31, Loss: 0.015
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.013
#
# Epoch: 7
# Batch 11, Loss: 0.009
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.015
#
# Epoch: 8
# Batch 11, Loss: 0.009
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.016
#
# Epoch: 9
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.013
#
# Epoch: 10
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.015
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.014
#
# Epoch: 11
# Batch 11, Loss: 0.009
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.012
#
# Epoch: 12
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.013
#
# Epoch: 13
# Batch 11, Loss: 0.009
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 14
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.010
#
# Epoch: 15
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.013
#
# Epoch: 16
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 17
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.012
#
# Epoch: 19
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.011
#
# Epoch: 20
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 1
# Batch 11, Loss: 7.071
# Batch 31, Loss: 11.172
# Batch 51, Loss: 10.586
# Batch 71, Loss: 9.524
#
# Epoch: 2
# Batch 11, Loss: 4.228
# Batch 31, Loss: 6.503
# Batch 51, Loss: 5.426
# Batch 71, Loss: 3.993
#
# Epoch: 3
# Batch 11, Loss: 1.480
# Batch 31, Loss: 1.964
# Batch 51, Loss: 1.629
# Batch 71, Loss: 1.361
#
# Epoch: 4
# Batch 11, Loss: 0.732
# Batch 31, Loss: 1.234
# Batch 51, Loss: 1.247
# Batch 71, Loss: 1.042
#
# Epoch: 5
# Batch 11, Loss: 0.540
# Batch 31, Loss: 0.946
# Batch 51, Loss: 0.806
# Batch 71, Loss: 0.664
#
# Epoch: 6
# Batch 11, Loss: 0.324
# Batch 31, Loss: 0.544
# Batch 51, Loss: 0.414
# Batch 71, Loss: 0.362
#
# Epoch: 7
# Batch 11, Loss: 0.146
# Batch 31, Loss: 0.221
# Batch 51, Loss: 0.139
# Batch 71, Loss: 0.086
#
# Epoch: 8
# Batch 11, Loss: 0.024
# Batch 31, Loss: 0.023
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.012
#
# Epoch: 9
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.011
#
# Epoch: 10
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 12
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 13
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 16
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 19
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.005
#
# Epoch: 1
# Batch 11, Loss: 10.368
# Batch 31, Loss: 18.083
# Batch 51, Loss: 15.537
# Batch 71, Loss: 13.550
#
# Epoch: 2
# Batch 11, Loss: 5.992
# Batch 31, Loss: 10.110
# Batch 51, Loss: 8.396
# Batch 71, Loss: 7.076
#
# Epoch: 3
# Batch 11, Loss: 2.821
# Batch 31, Loss: 4.781
# Batch 51, Loss: 3.326
# Batch 71, Loss: 2.782
#
# Epoch: 4
# Batch 11, Loss: 1.131
# Batch 31, Loss: 1.410
# Batch 51, Loss: 1.155
# Batch 71, Loss: 1.060
#
# Epoch: 5
# Batch 11, Loss: 0.534
# Batch 31, Loss: 1.020
# Batch 51, Loss: 0.962
# Batch 71, Loss: 1.016
#
# Epoch: 6
# Batch 11, Loss: 0.503
# Batch 31, Loss: 0.881
# Batch 51, Loss: 0.830
# Batch 71, Loss: 0.768
#
# Epoch: 7
# Batch 11, Loss: 0.400
# Batch 31, Loss: 0.714
# Batch 51, Loss: 0.647
# Batch 71, Loss: 0.569
#
# Epoch: 8
# Batch 11, Loss: 0.312
# Batch 31, Loss: 0.442
# Batch 51, Loss: 0.446
# Batch 71, Loss: 0.372
#
# Epoch: 9
# Batch 11, Loss: 0.164
# Batch 31, Loss: 0.223
# Batch 51, Loss: 0.201
# Batch 71, Loss: 0.141
#
# Epoch: 10
# Batch 11, Loss: 0.043
# Batch 31, Loss: 0.047
# Batch 51, Loss: 0.027
# Batch 71, Loss: 0.011
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 12
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 13
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 14
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 15
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.006
#
# Epoch: 16
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.005
#
# Epoch: 18
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.006
#
# Epoch: 1
# Batch 11, Loss: 3.954
# Batch 31, Loss: 6.241
# Batch 51, Loss: 4.718
# Batch 71, Loss: 3.306
#
# Epoch: 2
# Batch 11, Loss: 1.304
# Batch 31, Loss: 1.228
# Batch 51, Loss: 0.743
# Batch 71, Loss: 0.457
#
# Epoch: 3
# Batch 11, Loss: 0.154
# Batch 31, Loss: 0.179
# Batch 51, Loss: 0.112
# Batch 71, Loss: 0.038
#
# Epoch: 4
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 5
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.012
#
# Epoch: 6
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.011
#
# Epoch: 7
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 8
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 9
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 10
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 11
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 12
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 13
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.006
#
# Epoch: 14
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.006
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 16
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 1
# Batch 11, Loss: 11.977
# Batch 31, Loss: 18.482
# Batch 51, Loss: 16.928
# Batch 71, Loss: 15.602
#
# Epoch: 2
# Batch 11, Loss: 6.927
# Batch 31, Loss: 10.451
# Batch 51, Loss: 8.633
# Batch 71, Loss: 6.970
#
# Epoch: 3
# Batch 11, Loss: 2.402
# Batch 31, Loss: 3.355
# Batch 51, Loss: 2.249
# Batch 71, Loss: 1.487
#
# Epoch: 4
# Batch 11, Loss: 0.625
# Batch 31, Loss: 1.033
# Batch 51, Loss: 1.003
# Batch 71, Loss: 0.927
#
# Epoch: 5
# Batch 11, Loss: 0.436
# Batch 31, Loss: 0.699
# Batch 51, Loss: 0.586
# Batch 71, Loss: 0.385
#
# Epoch: 6
# Batch 11, Loss: 0.169
# Batch 31, Loss: 0.180
# Batch 51, Loss: 0.112
# Batch 71, Loss: 0.050
#
# Epoch: 7
# Batch 11, Loss: 0.021
# Batch 31, Loss: 0.026
# Batch 51, Loss: 0.020
# Batch 71, Loss: 0.010
#
# Epoch: 8
# Batch 11, Loss: 0.013
# Batch 31, Loss: 0.017
# Batch 51, Loss: 0.017
# Batch 71, Loss: 0.010
#
# Epoch: 9
# Batch 11, Loss: 0.011
# Batch 31, Loss: 0.015
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.011
#
# Epoch: 10
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.011
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.010
#
# Epoch: 12
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 13
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 14
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.008
#
# Epoch: 15
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 16
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 17
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 20
# Batch 11, Loss: 0.002
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.006
#
# Epoch: 1
# Batch 11, Loss: 10.455
# Batch 31, Loss: 16.760
# Batch 51, Loss: 12.627
# Batch 71, Loss: 11.250
#
# Epoch: 2
# Batch 11, Loss: 5.472
# Batch 31, Loss: 7.365
# Batch 51, Loss: 6.177
# Batch 71, Loss: 4.389
#
# Epoch: 3
# Batch 11, Loss: 1.971
# Batch 31, Loss: 2.473
# Batch 51, Loss: 1.762
# Batch 71, Loss: 1.321
#
# Epoch: 4
# Batch 11, Loss: 0.604
# Batch 31, Loss: 1.054
# Batch 51, Loss: 1.055
# Batch 71, Loss: 0.994
#
# Epoch: 5
# Batch 11, Loss: 0.433
# Batch 31, Loss: 0.798
# Batch 51, Loss: 0.762
# Batch 71, Loss: 0.591
#
# Epoch: 6
# Batch 11, Loss: 0.265
# Batch 31, Loss: 0.366
# Batch 51, Loss: 0.306
# Batch 71, Loss: 0.149
#
# Epoch: 7
# Batch 11, Loss: 0.038
# Batch 31, Loss: 0.024
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.014
#
# Epoch: 8
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.014
#
# Epoch: 9
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.011
#
# Epoch: 10
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.009
#
# Epoch: 11
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 12
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.007
#
# Epoch: 13
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 16
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.010
#
# Epoch: 1
# Batch 11, Loss: 0.701
# Batch 31, Loss: 1.269
# Batch 51, Loss: 1.153
# Batch 71, Loss: 1.148
#
# Epoch: 2
# Batch 11, Loss: 0.635
# Batch 31, Loss: 1.013
# Batch 51, Loss: 1.130
# Batch 71, Loss: 0.911
#
# Epoch: 3
# Batch 11, Loss: 0.571
# Batch 31, Loss: 0.856
# Batch 51, Loss: 0.764
# Batch 71, Loss: 0.776
#
# Epoch: 4
# Batch 11, Loss: 0.394
# Batch 31, Loss: 0.575
# Batch 51, Loss: 0.519
# Batch 71, Loss: 0.384
#
# Epoch: 5
# Batch 11, Loss: 0.188
# Batch 31, Loss: 0.197
# Batch 51, Loss: 0.130
# Batch 71, Loss: 0.069
#
# Epoch: 6
# Batch 11, Loss: 0.011
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 7
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 8
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 9
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 10
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 12
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 13
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 14
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 15
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 17
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.005
#
# Epoch: 18
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.006
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 1
# Batch 11, Loss: 5.178
# Batch 31, Loss: 8.054
# Batch 51, Loss: 7.704
# Batch 71, Loss: 6.705
#
# Epoch: 2
# Batch 11, Loss: 2.765
# Batch 31, Loss: 4.587
# Batch 51, Loss: 3.854
# Batch 71, Loss: 2.907
#
# Epoch: 3
# Batch 11, Loss: 0.994
# Batch 31, Loss: 1.482
# Batch 51, Loss: 1.387
# Batch 71, Loss: 1.049
#
# Epoch: 4
# Batch 11, Loss: 0.484
# Batch 31, Loss: 1.011
# Batch 51, Loss: 0.922
# Batch 71, Loss: 0.827
#
# Epoch: 5
# Batch 11, Loss: 0.390
# Batch 31, Loss: 0.546
# Batch 51, Loss: 0.443
# Batch 71, Loss: 0.391
#
# Epoch: 6
# Batch 11, Loss: 0.123
# Batch 31, Loss: 0.164
# Batch 51, Loss: 0.088
# Batch 71, Loss: 0.036
#
# Epoch: 7
# Batch 11, Loss: 0.009
# Batch 31, Loss: 0.015
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.013
#
# Epoch: 8
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 9
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.012
#
# Epoch: 10
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.015
#
# Epoch: 11
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.009
#
# Epoch: 12
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.011
#
# Epoch: 13
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.012
#
# Epoch: 15
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 16
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.011
#
# Epoch: 17
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 18
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.009
#
# Epoch: 19
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 1
# Batch 11, Loss: 2.969
# Batch 31, Loss: 4.115
# Batch 51, Loss: 2.935
# Batch 71, Loss: 1.763
#
# Epoch: 2
# Batch 11, Loss: 0.614
# Batch 31, Loss: 0.835
# Batch 51, Loss: 0.765
# Batch 71, Loss: 0.709
#
# Epoch: 3
# Batch 11, Loss: 0.325
# Batch 31, Loss: 0.536
# Batch 51, Loss: 0.415
# Batch 71, Loss: 0.339
#
# Epoch: 4
# Batch 11, Loss: 0.133
# Batch 31, Loss: 0.167
# Batch 51, Loss: 0.108
# Batch 71, Loss: 0.042
#
# Epoch: 5
# Batch 11, Loss: 0.010
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 6
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 7
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.006
#
# Epoch: 8
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 9
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 10
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.006
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.007
#
# Epoch: 12
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.006
#
# Epoch: 13
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 14
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 15
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.007
#
# Epoch: 16
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 17
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.006
#
# Epoch: 18
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.004
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.006
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.006
#
# Epoch: 1
# Batch 11, Loss: 1.245
# Batch 31, Loss: 1.546
# Batch 51, Loss: 1.358
# Batch 71, Loss: 1.158
#
# Epoch: 2
# Batch 11, Loss: 0.580
# Batch 31, Loss: 1.018
# Batch 51, Loss: 1.032
# Batch 71, Loss: 0.963
#
# Epoch: 3
# Batch 11, Loss: 0.501
# Batch 31, Loss: 0.851
# Batch 51, Loss: 0.668
# Batch 71, Loss: 0.701
#
# Epoch: 4
# Batch 11, Loss: 0.318
# Batch 31, Loss: 0.559
# Batch 51, Loss: 0.446
# Batch 71, Loss: 0.337
#
# Epoch: 5
# Batch 11, Loss: 0.131
# Batch 31, Loss: 0.155
# Batch 51, Loss: 0.084
# Batch 71, Loss: 0.038
#
# Epoch: 6
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 7
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 8
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 9
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 10
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.005
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 12
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 13
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.005
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.010
#
# Epoch: 14
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.006
#
# Epoch: 15
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.004
# Batch 71, Loss: 0.008
#
# Epoch: 16
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.006
#
# Epoch: 17
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.006
#
# Epoch: 18
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.005
#
# Epoch: 19
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.004
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.004
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.005
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.006
#
# Epoch: 1
# Batch 11, Loss: 8.571
# Batch 31, Loss: 13.123
# Batch 51, Loss: 10.207
# Batch 71, Loss: 8.579
#
# Epoch: 2
# Batch 11, Loss: 3.718
# Batch 31, Loss: 5.502
# Batch 51, Loss: 3.579
# Batch 71, Loss: 2.563
#
# Epoch: 3
# Batch 11, Loss: 0.765
# Batch 31, Loss: 0.932
# Batch 51, Loss: 0.568
# Batch 71, Loss: 0.603
#
# Epoch: 4
# Batch 11, Loss: 0.256
# Batch 31, Loss: 0.383
# Batch 51, Loss: 0.334
# Batch 71, Loss: 0.234
#
# Epoch: 5
# Batch 11, Loss: 0.058
# Batch 31, Loss: 0.075
# Batch 51, Loss: 0.026
# Batch 71, Loss: 0.012
#
# Epoch: 6
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.015
# Batch 71, Loss: 0.008
#
# Epoch: 7
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.013
#
# Epoch: 8
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 9
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 10
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 11
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 12
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 13
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 14
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 15
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 1
# Batch 11, Loss: 6.397
# Batch 31, Loss: 11.405
# Batch 51, Loss: 9.229
# Batch 71, Loss: 8.411
#
# Epoch: 2
# Batch 11, Loss: 3.658
# Batch 31, Loss: 6.695
# Batch 51, Loss: 5.823
# Batch 71, Loss: 5.393
#
# Epoch: 3
# Batch 11, Loss: 2.470
# Batch 31, Loss: 4.473
# Batch 51, Loss: 3.446
# Batch 71, Loss: 3.816
#
# Epoch: 4
# Batch 11, Loss: 1.804
# Batch 31, Loss: 2.645
# Batch 51, Loss: 2.149
# Batch 71, Loss: 1.499
#
# Epoch: 5
# Batch 11, Loss: 0.756
# Batch 31, Loss: 1.021
# Batch 51, Loss: 0.754
# Batch 71, Loss: 0.579
#
# Epoch: 6
# Batch 11, Loss: 0.253
# Batch 31, Loss: 0.443
# Batch 51, Loss: 0.343
# Batch 71, Loss: 0.269
#
# Epoch: 7
# Batch 11, Loss: 0.089
# Batch 31, Loss: 0.105
# Batch 51, Loss: 0.042
# Batch 71, Loss: 0.032
#
# Epoch: 8
# Batch 11, Loss: 0.012
# Batch 31, Loss: 0.030
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.016
#
# Epoch: 9
# Batch 11, Loss: 0.013
# Batch 31, Loss: 0.020
# Batch 51, Loss: 0.016
# Batch 71, Loss: 0.013
#
# Epoch: 10
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.019
# Batch 71, Loss: 0.015
#
# Epoch: 11
# Batch 11, Loss: 0.012
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.014
#
# Epoch: 12
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.018
# Batch 71, Loss: 0.013
#
# Epoch: 13
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.015
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.014
#
# Epoch: 14
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.014
#
# Epoch: 15
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.013
#
# Epoch: 16
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.011
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 18
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 19
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.011
#
# Epoch: 20
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 1
# Batch 11, Loss: 5.337
# Batch 31, Loss: 9.186
# Batch 51, Loss: 7.488
# Batch 71, Loss: 6.932
#
# Epoch: 2
# Batch 11, Loss: 3.221
# Batch 31, Loss: 5.145
# Batch 51, Loss: 4.027
# Batch 71, Loss: 3.401
#
# Epoch: 3
# Batch 11, Loss: 1.651
# Batch 31, Loss: 1.826
# Batch 51, Loss: 1.682
# Batch 71, Loss: 1.260
#
# Epoch: 4
# Batch 11, Loss: 0.460
# Batch 31, Loss: 0.921
# Batch 51, Loss: 0.816
# Batch 71, Loss: 0.709
#
# Epoch: 5
# Batch 11, Loss: 0.362
# Batch 31, Loss: 0.670
# Batch 51, Loss: 0.565
# Batch 71, Loss: 0.383
#
# Epoch: 6
# Batch 11, Loss: 0.227
# Batch 31, Loss: 0.237
# Batch 51, Loss: 0.200
# Batch 71, Loss: 0.140
#
# Epoch: 7
# Batch 11, Loss: 0.034
# Batch 31, Loss: 0.028
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.013
#
# Epoch: 8
# Batch 11, Loss: 0.010
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.009
#
# Epoch: 9
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.012
#
# Epoch: 10
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.009
#
# Epoch: 11
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 12
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.010
#
# Epoch: 13
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 14
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.008
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 18
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.011
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 20
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 1
# Batch 11, Loss: 2.619
# Batch 31, Loss: 3.938
# Batch 51, Loss: 3.391
# Batch 71, Loss: 2.480
#
# Epoch: 2
# Batch 11, Loss: 0.845
# Batch 31, Loss: 1.306
# Batch 51, Loss: 0.822
# Batch 71, Loss: 0.632
#
# Epoch: 3
# Batch 11, Loss: 0.336
# Batch 31, Loss: 0.548
# Batch 51, Loss: 0.477
# Batch 71, Loss: 0.393
#
# Epoch: 4
# Batch 11, Loss: 0.201
# Batch 31, Loss: 0.246
# Batch 51, Loss: 0.223
# Batch 71, Loss: 0.127
#
# Epoch: 5
# Batch 11, Loss: 0.044
# Batch 31, Loss: 0.040
# Batch 51, Loss: 0.015
# Batch 71, Loss: 0.011
#
# Epoch: 6
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 7
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.015
# Batch 71, Loss: 0.007
#
# Epoch: 8
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.013
#
# Epoch: 9
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 10
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.008
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.014
#
# Epoch: 12
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.011
#
# Epoch: 13
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.011
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 16
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 19
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 1
# Batch 11, Loss: 0.568
# Batch 31, Loss: 0.976
# Batch 51, Loss: 0.892
# Batch 71, Loss: 0.790
#
# Epoch: 2
# Batch 11, Loss: 0.385
# Batch 31, Loss: 0.677
# Batch 51, Loss: 0.563
# Batch 71, Loss: 0.407
#
# Epoch: 3
# Batch 11, Loss: 0.143
# Batch 31, Loss: 0.225
# Batch 51, Loss: 0.126
# Batch 71, Loss: 0.050
#
# Epoch: 4
# Batch 11, Loss: 0.012
# Batch 31, Loss: 0.015
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 5
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.010
#
# Epoch: 6
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 7
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.008
#
# Epoch: 8
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.011
#
# Epoch: 9
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 10
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 11
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 12
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 13
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 14
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 15
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 16
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 18
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 1
# Batch 11, Loss: 2.629
# Batch 31, Loss: 4.424
# Batch 51, Loss: 3.545
# Batch 71, Loss: 2.478
#
# Epoch: 2
# Batch 11, Loss: 0.956
# Batch 31, Loss: 1.354
# Batch 51, Loss: 1.005
# Batch 71, Loss: 0.828
#
# Epoch: 3
# Batch 11, Loss: 0.454
# Batch 31, Loss: 0.662
# Batch 51, Loss: 0.672
# Batch 71, Loss: 0.595
#
# Epoch: 4
# Batch 11, Loss: 0.236
# Batch 31, Loss: 0.384
# Batch 51, Loss: 0.320
# Batch 71, Loss: 0.232
#
# Epoch: 5
# Batch 11, Loss: 0.064
# Batch 31, Loss: 0.067
# Batch 51, Loss: 0.018
# Batch 71, Loss: 0.011
#
# Epoch: 6
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.011
#
# Epoch: 7
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.013
#
# Epoch: 8
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.007
#
# Epoch: 9
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 10
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.008
#
# Epoch: 11
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 12
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.012
#
# Epoch: 13
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.011
#
# Epoch: 14
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.010
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 1
# Batch 11, Loss: 4.710
# Batch 31, Loss: 7.744
# Batch 51, Loss: 6.900
# Batch 71, Loss: 6.043
#
# Epoch: 2
# Batch 11, Loss: 2.133
# Batch 31, Loss: 3.410
# Batch 51, Loss: 2.366
# Batch 71, Loss: 1.672
#
# Epoch: 3
# Batch 11, Loss: 0.668
# Batch 31, Loss: 1.005
# Batch 51, Loss: 1.062
# Batch 71, Loss: 0.962
#
# Epoch: 4
# Batch 11, Loss: 0.504
# Batch 31, Loss: 0.866
# Batch 51, Loss: 0.836
# Batch 71, Loss: 0.822
#
# Epoch: 5
# Batch 11, Loss: 0.420
# Batch 31, Loss: 0.706
# Batch 51, Loss: 0.685
# Batch 71, Loss: 0.681
#
# Epoch: 6
# Batch 11, Loss: 0.305
# Batch 31, Loss: 0.537
# Batch 51, Loss: 0.474
# Batch 71, Loss: 0.484
#
# Epoch: 7
# Batch 11, Loss: 0.202
# Batch 31, Loss: 0.355
# Batch 51, Loss: 0.274
# Batch 71, Loss: 0.223
#
# Epoch: 8
# Batch 11, Loss: 0.071
# Batch 31, Loss: 0.108
# Batch 51, Loss: 0.066
# Batch 71, Loss: 0.025
#
# Epoch: 9
# Batch 11, Loss: 0.010
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 10
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 11
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 12
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 13
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.010
#
# Epoch: 14
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 16
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.006
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.006
#
# Epoch: 18
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 1
# Batch 11, Loss: 1.287
# Batch 31, Loss: 1.926
# Batch 51, Loss: 1.350
# Batch 71, Loss: 1.073
#
# Epoch: 2
# Batch 11, Loss: 0.363
# Batch 31, Loss: 0.586
# Batch 51, Loss: 0.449
# Batch 71, Loss: 0.337
#
# Epoch: 3
# Batch 11, Loss: 0.088
# Batch 31, Loss: 0.189
# Batch 51, Loss: 0.101
# Batch 71, Loss: 0.041
#
# Epoch: 4
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 5
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 6
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 7
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 8
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.006
#
# Epoch: 9
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.010
#
# Epoch: 10
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 12
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 13
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.006
#
# Epoch: 17
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.004
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.011
#
# Epoch: 18
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.006
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 1
# Batch 11, Loss: 11.996
# Batch 31, Loss: 19.084
# Batch 51, Loss: 17.293
# Batch 71, Loss: 14.614
#
# Epoch: 2
# Batch 11, Loss: 7.016
# Batch 31, Loss: 10.399
# Batch 51, Loss: 9.369
# Batch 71, Loss: 6.943
#
# Epoch: 3
# Batch 11, Loss: 2.252
# Batch 31, Loss: 3.548
# Batch 51, Loss: 1.755
# Batch 71, Loss: 0.997
#
# Epoch: 4
# Batch 11, Loss: 0.328
# Batch 31, Loss: 0.467
# Batch 51, Loss: 0.389
# Batch 71, Loss: 0.237
#
# Epoch: 5
# Batch 11, Loss: 0.103
# Batch 31, Loss: 0.105
# Batch 51, Loss: 0.034
# Batch 71, Loss: 0.043
#
# Epoch: 6
# Batch 11, Loss: 0.014
# Batch 31, Loss: 0.025
# Batch 51, Loss: 0.018
# Batch 71, Loss: 0.023
#
# Epoch: 7
# Batch 11, Loss: 0.009
# Batch 31, Loss: 0.016
# Batch 51, Loss: 0.019
# Batch 71, Loss: 0.013
#
# Epoch: 8
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.013
#
# Epoch: 9
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.011
#
# Epoch: 10
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.008
#
# Epoch: 11
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 12
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.007
#
# Epoch: 13
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.007
#
# Epoch: 14
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 15
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 1
# Batch 11, Loss: 2.275
# Batch 31, Loss: 3.337
# Batch 51, Loss: 2.709
# Batch 71, Loss: 1.615
#
# Epoch: 2
# Batch 11, Loss: 0.531
# Batch 31, Loss: 0.730
# Batch 51, Loss: 0.576
# Batch 71, Loss: 0.526
#
# Epoch: 3
# Batch 11, Loss: 0.243
# Batch 31, Loss: 0.407
# Batch 51, Loss: 0.332
# Batch 71, Loss: 0.261
#
# Epoch: 4
# Batch 11, Loss: 0.087
# Batch 31, Loss: 0.123
# Batch 51, Loss: 0.051
# Batch 71, Loss: 0.024
#
# Epoch: 5
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 6
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 7
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 8
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 9
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 10
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 11
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 12
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 13
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 14
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 15
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 16
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 17
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.006
#
# Epoch: 18
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 1
# Batch 11, Loss: 2.968
# Batch 31, Loss: 4.674
# Batch 51, Loss: 3.703
# Batch 71, Loss: 3.246
#
# Epoch: 2
# Batch 11, Loss: 1.304
# Batch 31, Loss: 2.213
# Batch 51, Loss: 1.649
# Batch 71, Loss: 1.372
#
# Epoch: 3
# Batch 11, Loss: 0.608
# Batch 31, Loss: 0.962
# Batch 51, Loss: 0.912
# Batch 71, Loss: 0.869
#
# Epoch: 4
# Batch 11, Loss: 0.430
# Batch 31, Loss: 0.674
# Batch 51, Loss: 0.678
# Batch 71, Loss: 0.552
#
# Epoch: 5
# Batch 11, Loss: 0.194
# Batch 31, Loss: 0.364
# Batch 51, Loss: 0.176
# Batch 71, Loss: 0.136
#
# Epoch: 6
# Batch 11, Loss: 0.023
# Batch 31, Loss: 0.037
# Batch 51, Loss: 0.022
# Batch 71, Loss: 0.015
#
# Epoch: 7
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.018
# Batch 51, Loss: 0.017
# Batch 71, Loss: 0.016
#
# Epoch: 8
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.014
#
# Epoch: 9
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.013
#
# Epoch: 10
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.014
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 12
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 13
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 15
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.006
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 1
# Batch 11, Loss: 7.518
# Batch 31, Loss: 12.651
# Batch 51, Loss: 10.861
# Batch 71, Loss: 8.930
#
# Epoch: 2
# Batch 11, Loss: 3.342
# Batch 31, Loss: 6.045
# Batch 51, Loss: 4.922
# Batch 71, Loss: 3.813
#
# Epoch: 3
# Batch 11, Loss: 1.518
# Batch 31, Loss: 2.355
# Batch 51, Loss: 1.582
# Batch 71, Loss: 1.219
#
# Epoch: 4
# Batch 11, Loss: 0.503
# Batch 31, Loss: 0.806
# Batch 51, Loss: 0.800
# Batch 71, Loss: 0.648
#
# Epoch: 5
# Batch 11, Loss: 0.328
# Batch 31, Loss: 0.461
# Batch 51, Loss: 0.314
# Batch 71, Loss: 0.264
#
# Epoch: 6
# Batch 11, Loss: 0.077
# Batch 31, Loss: 0.075
# Batch 51, Loss: 0.038
# Batch 71, Loss: 0.016
#
# Epoch: 7
# Batch 11, Loss: 0.018
# Batch 31, Loss: 0.019
# Batch 51, Loss: 0.016
# Batch 71, Loss: 0.017
#
# Epoch: 8
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.016
# Batch 51, Loss: 0.017
# Batch 71, Loss: 0.011
#
# Epoch: 9
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.010
#
# Epoch: 10
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 11
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 12
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 13
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.008
#
# Epoch: 14
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 16
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.007
#
# Epoch: 17
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.007
#
# Epoch: 19
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.006
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.006
#
# Epoch: 1
# Batch 11, Loss: 2.489
# Batch 31, Loss: 4.027
# Batch 51, Loss: 2.990
# Batch 71, Loss: 2.319
#
# Epoch: 2
# Batch 11, Loss: 0.854
# Batch 31, Loss: 1.583
# Batch 51, Loss: 1.091
# Batch 71, Loss: 0.998
#
# Epoch: 3
# Batch 11, Loss: 0.510
# Batch 31, Loss: 0.788
# Batch 51, Loss: 0.827
# Batch 71, Loss: 0.589
#
# Epoch: 4
# Batch 11, Loss: 0.314
# Batch 31, Loss: 0.471
# Batch 51, Loss: 0.371
# Batch 71, Loss: 0.270
#
# Epoch: 5
# Batch 11, Loss: 0.078
# Batch 31, Loss: 0.090
# Batch 51, Loss: 0.032
# Batch 71, Loss: 0.013
#
# Epoch: 6
# Batch 11, Loss: 0.014
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.016
# Batch 71, Loss: 0.013
#
# Epoch: 7
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.015
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.011
#
# Epoch: 8
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.013
#
# Epoch: 9
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.013
#
# Epoch: 10
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.011
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.013
#
# Epoch: 12
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 13
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 14
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 15
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 16
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 18
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 1
# Batch 11, Loss: 0.802
# Batch 31, Loss: 1.331
# Batch 51, Loss: 1.267
# Batch 71, Loss: 0.915
#
# Epoch: 2
# Batch 11, Loss: 0.469
# Batch 31, Loss: 0.798
# Batch 51, Loss: 0.903
# Batch 71, Loss: 0.736
#
# Epoch: 3
# Batch 11, Loss: 0.387
# Batch 31, Loss: 0.584
# Batch 51, Loss: 0.457
# Batch 71, Loss: 0.363
#
# Epoch: 4
# Batch 11, Loss: 0.143
# Batch 31, Loss: 0.172
# Batch 51, Loss: 0.105
# Batch 71, Loss: 0.042
#
# Epoch: 5
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.009
#
# Epoch: 6
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.010
#
# Epoch: 7
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# ...
# Batch 71, Loss: 0.006
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 20
# Batch 11, Loss: 0.002
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 1
# Batch 11, Loss: 0.811
# Batch 31, Loss: 1.250
# Batch 51, Loss: 1.343
# Batch 71, Loss: 1.426
#
# Epoch: 2
# Batch 11, Loss: 0.791
# Batch 31, Loss: 1.193
# Batch 51, Loss: 1.211
# Batch 71, Loss: 1.164
#
# Epoch: 3
# Batch 11, Loss: 0.624
# Batch 31, Loss: 1.140
# Batch 51, Loss: 0.976
# Batch 71, Loss: 0.974
#
# Epoch: 4
# Batch 11, Loss: 0.530
# Batch 31, Loss: 0.811
# Batch 51, Loss: 0.824
# Batch 71, Loss: 0.638
#
# Epoch: 5
# Batch 11, Loss: 0.262
# Batch 31, Loss: 0.494
# Batch 51, Loss: 0.400
# Batch 71, Loss: 0.297
#
# Epoch: 6
# Batch 11, Loss: 0.069
# Batch 31, Loss: 0.077
# Batch 51, Loss: 0.036
# Batch 71, Loss: 0.026
#
# Epoch: 7
# Batch 11, Loss: 0.010
# Batch 31, Loss: 0.018
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.016
#
# Epoch: 8
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.012
#
# Epoch: 9
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 10
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 11
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 12
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 13
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 15
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 16
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 17
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.008
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.006
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 1
# Batch 11, Loss: 9.818
# Batch 31, Loss: 15.708
# Batch 51, Loss: 14.151
# Batch 71, Loss: 11.265
#
# Epoch: 2
# Batch 11, Loss: 4.344
# Batch 31, Loss: 6.787
# Batch 51, Loss: 4.898
# Batch 71, Loss: 3.309
#
# Epoch: 3
# Batch 11, Loss: 1.083
# Batch 31, Loss: 1.301
# Batch 51, Loss: 1.064
# Batch 71, Loss: 1.070
#
# Epoch: 4
# Batch 11, Loss: 0.581
# Batch 31, Loss: 0.900
# Batch 51, Loss: 0.868
# Batch 71, Loss: 0.906
#
# Epoch: 5
# Batch 11, Loss: 0.402
# Batch 31, Loss: 0.751
# Batch 51, Loss: 0.641
# Batch 71, Loss: 0.594
#
# Epoch: 6
# Batch 11, Loss: 0.260
# Batch 31, Loss: 0.487
# Batch 51, Loss: 0.405
# Batch 71, Loss: 0.318
#
# Epoch: 7
# Batch 11, Loss: 0.103
# Batch 31, Loss: 0.161
# Batch 51, Loss: 0.122
# Batch 71, Loss: 0.068
#
# Epoch: 8
# Batch 11, Loss: 0.024
# Batch 31, Loss: 0.022
# Batch 51, Loss: 0.015
# Batch 71, Loss: 0.015
#
# Epoch: 9
# Batch 11, Loss: 0.011
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.011
#
# Epoch: 10
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.012
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 12
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 13
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 14
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.010
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 16
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 19
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 1
# Batch 11, Loss: 0.920
# Batch 31, Loss: 1.316
# Batch 51, Loss: 1.164
# Batch 71, Loss: 1.039
#
# Epoch: 2
# Batch 11, Loss: 0.521
# Batch 31, Loss: 0.743
# Batch 51, Loss: 0.629
# Batch 71, Loss: 0.504
#
# Epoch: 3
# Batch 11, Loss: 0.205
# Batch 31, Loss: 0.276
# Batch 51, Loss: 0.167
# Batch 71, Loss: 0.096
#
# Epoch: 4
# Batch 11, Loss: 0.015
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.013
#
# Epoch: 5
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.009
#
# Epoch: 6
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 7
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 8
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 9
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 10
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 11
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 12
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 13
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 15
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 19
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 1
# Batch 11, Loss: 0.866
# Batch 31, Loss: 1.680
# Batch 51, Loss: 1.533
# Batch 71, Loss: 1.382
#
# Epoch: 2
# Batch 11, Loss: 0.800
# Batch 31, Loss: 1.584
# Batch 51, Loss: 1.346
# Batch 71, Loss: 1.324
#
# Epoch: 3
# Batch 11, Loss: 0.819
# Batch 31, Loss: 1.288
# Batch 51, Loss: 1.288
# Batch 71, Loss: 1.335
#
# Epoch: 4
# Batch 11, Loss: 0.692
# Batch 31, Loss: 1.241
# Batch 51, Loss: 1.218
# Batch 71, Loss: 1.251
#
# Epoch: 5
# Batch 11, Loss: 0.588
# Batch 31, Loss: 1.066
# Batch 51, Loss: 1.166
# Batch 71, Loss: 1.062
#
# Epoch: 6
# Batch 11, Loss: 0.549
# Batch 31, Loss: 0.960
# Batch 51, Loss: 0.847
# Batch 71, Loss: 0.673
#
# Epoch: 7
# Batch 11, Loss: 0.355
# Batch 31, Loss: 0.560
# Batch 51, Loss: 0.491
# Batch 71, Loss: 0.409
#
# Epoch: 8
# Batch 11, Loss: 0.137
# Batch 31, Loss: 0.227
# Batch 51, Loss: 0.123
# Batch 71, Loss: 0.072
#
# Epoch: 9
# Batch 11, Loss: 0.013
# Batch 31, Loss: 0.024
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.019
#
# Epoch: 10
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.015
# Batch 51, Loss: 0.015
# Batch 71, Loss: 0.016
#
# Epoch: 11
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.017
# Batch 71, Loss: 0.012
#
# Epoch: 12
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.011
#
# Epoch: 13
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.012
#
# Epoch: 14
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 15
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.010
#
# Epoch: 16
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 17
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 18
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.007
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 1
# Batch 11, Loss: 1.159
# Batch 31, Loss: 1.967
# Batch 51, Loss: 1.826
# Batch 71, Loss: 1.549
#
# Epoch: 2
# Batch 11, Loss: 0.824
# Batch 31, Loss: 1.287
# Batch 51, Loss: 1.247
# Batch 71, Loss: 1.187
#
# Epoch: 3
# Batch 11, Loss: 0.553
# Batch 31, Loss: 1.169
# Batch 51, Loss: 1.015
# Batch 71, Loss: 0.969
#
# Epoch: 4
# Batch 11, Loss: 0.428
# Batch 31, Loss: 0.738
# Batch 51, Loss: 0.729
# Batch 71, Loss: 0.682
#
# Epoch: 5
# Batch 11, Loss: 0.262
# Batch 31, Loss: 0.351
# Batch 51, Loss: 0.251
# Batch 71, Loss: 0.114
#
# Epoch: 6
# Batch 11, Loss: 0.025
# Batch 31, Loss: 0.029
# Batch 51, Loss: 0.018
# Batch 71, Loss: 0.022
#
# Epoch: 7
# Batch 11, Loss: 0.012
# Batch 31, Loss: 0.018
# Batch 51, Loss: 0.017
# Batch 71, Loss: 0.019
#
# Epoch: 8
# Batch 11, Loss: 0.013
# Batch 31, Loss: 0.017
# Batch 51, Loss: 0.015
# Batch 71, Loss: 0.015
#
# Epoch: 9
# Batch 11, Loss: 0.011
# Batch 31, Loss: 0.018
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.013
#
# Epoch: 10
# Batch 11, Loss: 0.009
# Batch 31, Loss: 0.016
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.013
#
# Epoch: 11
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.015
#
# Epoch: 12
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.014
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.011
#
# Epoch: 13
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 15
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 16
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 17
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 19
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 1
# Batch 11, Loss: 4.802
# Batch 31, Loss: 7.489
# Batch 51, Loss: 6.813
# Batch 71, Loss: 5.566
#
# Epoch: 2
# Batch 11, Loss: 1.940
# Batch 31, Loss: 3.064
# Batch 51, Loss: 2.103
# Batch 71, Loss: 1.796
#
# Epoch: 3
# Batch 11, Loss: 0.745
# Batch 31, Loss: 1.187
# Batch 51, Loss: 1.032
# Batch 71, Loss: 1.173
#
# Epoch: 4
# Batch 11, Loss: 0.610
# Batch 31, Loss: 0.881
# Batch 51, Loss: 0.937
# Batch 71, Loss: 0.940
#
# Epoch: 5
# Batch 11, Loss: 0.448
# Batch 31, Loss: 0.683
# Batch 51, Loss: 0.673
# Batch 71, Loss: 0.602
#
# Epoch: 6
# Batch 11, Loss: 0.235
# Batch 31, Loss: 0.413
# Batch 51, Loss: 0.304
# Batch 71, Loss: 0.181
#
# Epoch: 7
# Batch 11, Loss: 0.058
# Batch 31, Loss: 0.050
# Batch 51, Loss: 0.018
# Batch 71, Loss: 0.009
#
# Epoch: 8
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.007
#
# Epoch: 9
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 10
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.006
#
# Epoch: 11
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.011
#
# Epoch: 12
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 13
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.007
#
# Epoch: 16
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.005
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 20
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 1
# Batch 11, Loss: 1.312
# Batch 31, Loss: 1.500
# Batch 51, Loss: 1.334
# Batch 71, Loss: 1.056
#
# Epoch: 2
# Batch 11, Loss: 0.475
# Batch 31, Loss: 0.959
# Batch 51, Loss: 0.798
# Batch 71, Loss: 0.637
#
# Epoch: 3
# Batch 11, Loss: 0.278
# Batch 31, Loss: 0.356
# Batch 51, Loss: 0.210
# Batch 71, Loss: 0.116
#
# Epoch: 4
# Batch 11, Loss: 0.023
# Batch 31, Loss: 0.018
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.014
#
# Epoch: 5
# Batch 11, Loss: 0.009
# Batch 31, Loss: 0.013
# Batch 51, Loss: 0.014
# Batch 71, Loss: 0.011
#
# Epoch: 6
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.015
# Batch 51, Loss: 0.013
# Batch 71, Loss: 0.009
#
# Epoch: 7
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.012
# Batch 71, Loss: 0.012
#
# Epoch: 8
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 9
# Batch 11, Loss: 0.008
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 10
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.013
#
# Epoch: 11
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.009
#
# Epoch: 12
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 13
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 15
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 16
# Batch 11, Loss: 0.007
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 17
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 18
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 19
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.011
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.006
#
# Epoch: 1
# Batch 11, Loss: 0.749
# Batch 31, Loss: 1.300
# Batch 51, Loss: 1.044
# Batch 71, Loss: 1.086
#
# Epoch: 2
# Batch 11, Loss: 0.469
# Batch 31, Loss: 0.927
# Batch 51, Loss: 0.751
# Batch 71, Loss: 0.759
#
# Epoch: 3
# Batch 11, Loss: 0.222
# Batch 31, Loss: 0.480
# Batch 51, Loss: 0.360
# Batch 71, Loss: 0.235
#
# Epoch: 4
# Batch 11, Loss: 0.057
# Batch 31, Loss: 0.044
# Batch 51, Loss: 0.011
# Batch 71, Loss: 0.009
#
# Epoch: 5
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 71, Loss: 0.007
#
# Epoch: 6
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 7
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.006
# Batch 71, Loss: 0.009
#
# Epoch: 8
# Batch 11, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.008
#
# Epoch: 9
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.007
#
# Epoch: 10
# Batch 11, Loss: 0.005
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 11
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.005
#
# Epoch: 12
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.005
#
# Epoch: 13
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 14
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.006
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 15
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.007
#
# Epoch: 16
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.005
# Batch 71, Loss: 0.006
#
# Epoch: 17
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.006
#
# Epoch: 18
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.007
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.005
#
# Epoch: 19
# Batch 11, Loss: 0.004
# Batch 31, Loss: 0.005
# Batch 51, Loss: 0.008
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 11, Loss: 0.003
# Batch 31, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 71, Loss: 0.006

# %%
len(df_fw_list[0])
# Out:
# 909

# %%
len(X_train_list[0])
# Out:
# 904

# %%
df = df_fw_list[0]
X_train = X_train_list[0]
scaler = scaler_list[0]

fig = go.Figure()


actual_y_scat = go.Scatter(x=df['ds'][lookback:], y=df['y'][lookback:], mode='lines', name="y", line=dict(color='red'))
predicted_y = get_predict(model=model,X=X_train, scaler=scaler)
predict_y_scat = go.Scatter(x=df['ds'][lookback:], y=predicted_y, mode='lines', name='yhat', line=dict(color='blue'))
fig.add_trace(actual_y_scat)
fig.add_trace(predict_y_scat)

# Adjust layout for better spacing
fig.update_layout(title_text=f"Training forward form {origin_start_date.strftime('%Y-%m-%d')} up upper bound date")
fig.update_xaxes(title_text='Date')  # Set X-axis label for the bottom subplot
fig.update_yaxes(title_text='Price')  # Set Y-axis label for the left subplot
# Show the figure
fig.show()

# %% [markdown]
# #### Forward Evaluate Model

# %%
def get_list_next_day_predict_test_range():
    next_days = []
    for model, scaler, shifted_df_as_np_scaler in zip(list_model, scaler_list, shifted_df_as_np_scaler_list):
      next_day_predict = get_predict_next_day(model, scaler, shifted_df_as_np_scaler,1)
      next_days.append(next_day_predict)
    
    return np.array(next_days).reshape(len(next_days))


def create_evalute_table():
    next_days = get_list_next_day_predict_test_range()
    df = get_list_next_day_actual_test_range()
    df['predict'] = pd.Series(next_days)
    df[['ds','y','yhat']] = df[['time','close','predict']]
    df = df[['ds','y','yhat']]
    df['ds'] = pd.to_datetime(df['ds'])
    return df

# %%
df_eval = create_evalute_table()
df_eval['y_change'] = df_eval['y'].diff()
df_eval['yhat_change'] = df_eval['yhat'].diff()
df_eval['y*yhat_chage'] = df_eval['y_change'] * df_eval['yhat_change']

# %%
df_eval
# Out:
#            ds      y          yhat  y_change  yhat_change  y*yhat_chage
# 0  2023-08-22  85500  81786.497418       NaN          NaN           NaN
# 1  2023-08-23  85500  81882.447184       0.0    95.949767  0.000000e+00
# 2  2023-08-24  90000  83568.784479    4500.0  1686.337295  7.588518e+06
# 3  2023-08-25  90600  83058.410234     600.0  -510.374244 -3.062245e+05
# 4  2023-08-28  94000  85068.972263    3400.0  2010.562029  6.835911e+06
# ..        ...    ...           ...       ...          ...           ...
# 84 2023-12-20  94700  94988.200417     100.0  -193.995781 -1.939958e+04
# 85 2023-12-21  95100  95077.439041     400.0    89.238625  3.569545e+04
# 86 2023-12-22  94600  93710.847168    -500.0 -1366.591873  6.832959e+05
# 87 2023-12-25  96000  94033.268929    1400.0   322.421761  4.513905e+05
# 88 2023-12-26  97200  94246.815987    1200.0   213.547058  2.562565e+05
#
# [89 rows x 6 columns]

# %%
from sklearn.metrics import r2_score

# %%
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(df_eval['y'], df_eval['yhat']))
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Calculate correlation coefficient
correlation = df_eval['y'].corr(df_eval['yhat'])
print(f"Correlation Coefficient: {correlation}")

truth = []
for y_hat_change, y_change in zip(df_eval['yhat'].diff().dropna(),df_eval['y'].diff().dropna()):
    truth.append(1 if y_hat_change * y_change > 0 else 0)


print(f"Direction correction ratio: {np.sum(truth)/len(truth) * 100}")

r2 = r2_score(df_eval['y'], df_eval['yhat'])
print(f"R-squared (R²): {r2}")
# Out:
# Root Mean Squared Error (RMSE): 3441.145454159429
# Correlation Coefficient: 0.6183306944526348
# Direction correction ratio: 46.590909090909086
# R-squared (R²): 0.008412336962540512

# %%
df_mtr = pd.read_csv('./output/metrics-FPT.csv')
# remove old record
df_mtr = df_mtr[~(df_mtr['model'] == 'LSTM(1,4,1)')]

df_mtr = pd.concat([df_mtr,
                    pd.DataFrame({
                     'model': ['LSTM(1,4,1)'],
                     'rmse': [rmse],
                     'correlation': [correlation],
                     'r-squared': [r2] })], axis=0)
df_mtr.to_csv('./output/metrics-FPT.csv',index=False)

# %%
# Plotting with Plotly
fig = go.Figure()

# Plot yhat as a line
fig.add_trace(go.Scatter(x=df_eval['ds'], y=df_eval['yhat'], mode='lines+markers', name='yhat', line=dict(color='blue')))

# Plot y as points
fig.add_trace(go.Scatter(x=df_eval['ds'], y=df_eval['y'], mode='lines+markers', name='y', marker=dict(color='red', size=8)))

# Set layout
fig.update_layout(title=f'{stock_target} moving forward train and predict the next day',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  showlegend=True)

# Show the plot
fig.show()

# %%
marker_colors = ['red' if value < 0 else 'green' for value in df_eval['y*yhat_chage']]

trace = go.Scatter(x=df['ds'], y=df_eval['y*yhat_chage'], mode='lines+markers', name='Result Array', marker=dict(color=marker_colors))

# Create layout
layout = go.Layout(title='Line with Markers for Result Array', xaxis=dict(title='Index'), yaxis=dict(title='Value'))

# Create figure and add trace
fig = go.Figure(data=[trace], layout=layout)

# Show the plot
fig.show()

# %%
import plotly.express as px

scaler_corr = MinMaxScaler(feature_range=(-1, 1)) 

# Here we use a column with categorical data
fig = px.histogram(scaler_corr.fit_transform(df_eval['y*yhat_chage'].to_numpy().reshape(-1, 1)), nbins=60)
fig.show()

# %%
df_eval['y_rolling_7_std'] = df_eval['y_change'].rolling(window=7).std()
df_eval['yhat_rolling_7_std'] = df_eval['yhat_change'].rolling(window=7).std()
df_eval['y*yhat_chage_rolling_7'] =  df_eval['y*yhat_chage'].rolling(window=7).mean()
df_eval['moving_corr'] = df_eval['y*yhat_chage_rolling_7'] / (df_eval['y_rolling_7_std'] * df_eval['yhat_rolling_7_std'])

# %%
scaler_corr = MinMaxScaler(feature_range=(-1, 1)) 

# Here we use a column with categorical data
fig = px.histogram(df_eval['moving_corr'], nbins=60)
fig.show()

# %%
df_eval
# Out:
#            ds      y          yhat  y_change  yhat_change  y*yhat_chage  \
# 0  2023-08-22  85500  81786.497418       NaN          NaN           NaN
# 1  2023-08-23  85500  81882.447184       0.0    95.949767  0.000000e+00
# 2  2023-08-24  90000  83568.784479    4500.0  1686.337295  7.588518e+06
# 3  2023-08-25  90600  83058.410234     600.0  -510.374244 -3.062245e+05
# 4  2023-08-28  94000  85068.972263    3400.0  2010.562029  6.835911e+06
# ..        ...    ...           ...       ...          ...           ...
# 84 2023-12-20  94700  94988.200417     100.0  -193.995781 -1.939958e+04
# 85 2023-12-21  95100  95077.439041     400.0    89.238625  3.569545e+04
# 86 2023-12-22  94600  93710.847168    -500.0 -1366.591873  6.832959e+05
# 87 2023-12-25  96000  94033.268929    1400.0   322.421761  4.513905e+05
# 88 2023-12-26  97200  94246.815987    1200.0   213.547058  2.562565e+05
#
#     y_rolling_7_std  yhat_rolling_7_std  y*yhat_chage_rolling_7  moving_corr
# 0               NaN                 NaN                     NaN          NaN
# 1               NaN                 NaN                     NaN          NaN
# 2               NaN                 NaN                     NaN          NaN
# 3               NaN                 NaN                     NaN          NaN
# 4               NaN                 NaN                     NaN          NaN
# ..              ...                 ...                     ...          ...
# 84      1414.045194          959.176333             3183.122907     0.002347
# 85      1191.437707          679.536094          -466834.156581    -0.576605
# 86      1046.308704          869.522883          -424414.682661    -0.466498
# 87      1123.557276          785.889876          -220497.082847    -0.249716
# 88      1216.356777          782.301066          -183889.015743    -0.193251
#
# [89 rows x 10 columns]
