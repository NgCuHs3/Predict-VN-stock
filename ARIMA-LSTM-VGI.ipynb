# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from vnstock import *
from datetime import datetime
from sklearn.metrics import mean_squared_error
from vnstock.chart import * # import chart functions
from prophet import Prophet
from prophet.plot import plot_plotly,plot_components_plotly
from prophet.plot import add_changepoints_to_plot
from prophet.diagnostics import performance_metrics
from prophet.diagnostics import cross_validation
import itertools
import torch
from copy import deepcopy as dc
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import torch.nn as nn
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# Set Matplotlib defaults
sns.set_style('whitegrid')
plt.rc("figure", autolayout=True, figsize=(15, 8))
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    legend=False,
)

# %%
df = stock_historical_data(symbol="VGI", start_date="2020-01-02", end_date="2023-12-25", resolution="1D", type="stock", beautify=True, decor=False, source='DNSE')

# %%
fig = candlestick_chart(df, ma_periods=[50,200], show_volume=False, reference_period=300, figure_size=(12, 6),
                        title='VGI - Candlestick Chart with MA and Volume', x_label='Date', y_label='Price',
                        colors=('lightgray', 'gray'), reference_colors=('black', 'blue'))

fig.show()

# %% [markdown]
# ### Prepare data

# %%
# config
stock_target='VGI'
origin_start_date= datetime(2020, 1, 2)
start_date = datetime(2023, 8, 20)
end_date = datetime(2023, 12, 25)

# %%
def move_day(today): 
    if today.weekday() == 5:  # Saturday
     today += timedelta(days=2)
    elif today.weekday() == 6:  # Sunday
     today += timedelta(days=1)
    return today

def generate_date_range(start_date, end_date):
    # mapping to stock is that day exist 
    df_map = stock_historical_data(symbol=stock_target, start_date=start_date.strftime('%Y-%m-%d'),end_date=end_date.strftime('%Y-%m-%d'), resolution="1D", type="stock", beautify=True, decor=False, source='DNSE')
        
    return pd.to_datetime(df_map['time'])

def restore_df(X_scaler,y_scaler,scaler):

   num_features = 0
   # (number samples, number time steps, number features)
   if X_scaler.shape[1] == 1:
      num_features = X_scaler.shape[2]
   elif  X_scaler.shape[2] == 1:
      num_features = X_scaler.shape[1]  

   dummies = np.zeros((X_scaler.shape[0],num_features + 1))

   if  X_scaler.shape[1] == 1:
        # don't use timestep instead use features
       dummies[:,1:] = X_scaler.reshape((X_scaler.shape[0],X_scaler.shape[2]))
   elif X_scaler.shape[1] != 1:
       # use time steps
       dummies[:,1:] = X_scaler.reshape((X_scaler.shape[0],X_scaler.shape[1]))
   dummies[:, 0] = y_scaler.flatten()
   df = scaler.inverse_transform(dummies)
   return df

def get_predict_and_df(model, X, scaler):
    if not torch.is_tensor(X):
        X = torch.tensor(X).float() 
    
    with torch.no_grad():
       y_predicted = model(X.to(device)).to('cpu').numpy()
      
    y_predict = y_predicted.flatten()
    df = restore_df(X, y_predict, scaler)
    return df
   
def get_predict(model, X, scaler):
    with torch.no_grad():
      df = get_predict_and_df(model, X, scaler)
      return df[:,:1].reshape(df.shape[0])
    
def create_scaler_df(df):
     df_np = df.to_numpy()
     scaler = MinMaxScaler(feature_range = (0, 1))
     df_np_scaler = scaler.fit_transform(df_np)
     return df_np_scaler, scaler

def multi_scaler_df(df_list):
    df_np_scaler_list = []
    scaler_list = []
    for df in df_list:    
      df_np_scaler, scaler = create_scaler_df(df)
      df_np_scaler_list.append(df_np_scaler)
      scaler_list.append(scaler)
    return df_np_scaler_list, scaler_list

# %%
day_test_range = generate_date_range(start_date,end_date)

# %%
len(day_test_range)
# Out:
# 88

# %%
def get_list_next_day_actual_test_range():
    begin_day = (day_test_range.iloc[0] + timedelta(days=1)).strftime('%Y-%m-%d')
    stop_day = (day_test_range.iloc[-1] + timedelta(days=1)).strftime('%Y-%m-%d')
    df_raw = stock_historical_data(symbol=stock_target, start_date=begin_day,end_date=stop_day, resolution="1D", type="stock", beautify=True, decor=False, source='DNSE')
    return df_raw

# %% [markdown]
# **Get the data**

# %%
df_fw_list = []
print("Get stock data from origin data 2020-01-02 to latest test day "+ end_date.strftime('%Y-%m-%d'))
df_raw = stock_historical_data(symbol=stock_target, start_date=origin_start_date.strftime('%Y-%m-%d') ,end_date=end_date.strftime('%Y-%m-%d'), resolution="1D", type="stock", beautify=True, decor=False, source='DNSE')
df_fw_gen = pd.DataFrame()
df_fw_gen[['ds','y']] = df_raw[['time','close']]
df_fw_gen['ds'] = pd.to_datetime(df_fw_gen['ds'] )

for upper_bound_date in  day_test_range:
    df_fw = dc(df_fw_gen[ df_fw_gen['ds'] <= upper_bound_date])
    print(f"Create samples set from {origin_start_date.strftime('%Y-%m-%d')} to {upper_bound_date.strftime('%Y-%m-%d')}")
    df_fw = df_fw.groupby('ds').mean().reset_index()
    df_fw_list.append(df_fw)
# Out:
# Get stock data from origin data 2020-01-02 to latest test day 2023-12-25
# Create samples set from 2020-01-02 to 2023-08-21
# Create samples set from 2020-01-02 to 2023-08-22
# Create samples set from 2020-01-02 to 2023-08-23
# Create samples set from 2020-01-02 to 2023-08-24
# Create samples set from 2020-01-02 to 2023-08-25
# Create samples set from 2020-01-02 to 2023-08-28
# Create samples set from 2020-01-02 to 2023-08-29
# Create samples set from 2020-01-02 to 2023-08-30
# Create samples set from 2020-01-02 to 2023-08-31
# Create samples set from 2020-01-02 to 2023-09-05
# Create samples set from 2020-01-02 to 2023-09-06
# Create samples set from 2020-01-02 to 2023-09-07
# Create samples set from 2020-01-02 to 2023-09-08
# Create samples set from 2020-01-02 to 2023-09-11
# Create samples set from 2020-01-02 to 2023-09-12
# Create samples set from 2020-01-02 to 2023-09-13
# Create samples set from 2020-01-02 to 2023-09-14
# Create samples set from 2020-01-02 to 2023-09-15
# Create samples set from 2020-01-02 to 2023-09-18
# Create samples set from 2020-01-02 to 2023-09-19
# Create samples set from 2020-01-02 to 2023-09-20
# Create samples set from 2020-01-02 to 2023-09-21
# Create samples set from 2020-01-02 to 2023-09-22
# Create samples set from 2020-01-02 to 2023-09-25
# Create samples set from 2020-01-02 to 2023-09-26
# Create samples set from 2020-01-02 to 2023-09-27
# Create samples set from 2020-01-02 to 2023-09-28
# Create samples set from 2020-01-02 to 2023-09-29
# Create samples set from 2020-01-02 to 2023-10-02
# Create samples set from 2020-01-02 to 2023-10-03
# Create samples set from 2020-01-02 to 2023-10-04
# Create samples set from 2020-01-02 to 2023-10-05
# Create samples set from 2020-01-02 to 2023-10-06
# Create samples set from 2020-01-02 to 2023-10-09
# Create samples set from 2020-01-02 to 2023-10-10
# Create samples set from 2020-01-02 to 2023-10-11
# Create samples set from 2020-01-02 to 2023-10-12
# Create samples set from 2020-01-02 to 2023-10-16
# Create samples set from 2020-01-02 to 2023-10-17
# Create samples set from 2020-01-02 to 2023-10-18
# Create samples set from 2020-01-02 to 2023-10-19
# Create samples set from 2020-01-02 to 2023-10-20
# Create samples set from 2020-01-02 to 2023-10-23
# Create samples set from 2020-01-02 to 2023-10-24
# Create samples set from 2020-01-02 to 2023-10-25
# Create samples set from 2020-01-02 to 2023-10-26
# Create samples set from 2020-01-02 to 2023-10-27
# Create samples set from 2020-01-02 to 2023-10-30
# Create samples set from 2020-01-02 to 2023-10-31
# Create samples set from 2020-01-02 to 2023-11-01
# Create samples set from 2020-01-02 to 2023-11-02
# Create samples set from 2020-01-02 to 2023-11-03
# Create samples set from 2020-01-02 to 2023-11-06
# Create samples set from 2020-01-02 to 2023-11-07
# Create samples set from 2020-01-02 to 2023-11-08
# Create samples set from 2020-01-02 to 2023-11-09
# Create samples set from 2020-01-02 to 2023-11-10
# Create samples set from 2020-01-02 to 2023-11-13
# Create samples set from 2020-01-02 to 2023-11-14
# Create samples set from 2020-01-02 to 2023-11-15
# Create samples set from 2020-01-02 to 2023-11-16
# Create samples set from 2020-01-02 to 2023-11-17
# Create samples set from 2020-01-02 to 2023-11-20
# Create samples set from 2020-01-02 to 2023-11-21
# Create samples set from 2020-01-02 to 2023-11-22
# Create samples set from 2020-01-02 to 2023-11-23
# Create samples set from 2020-01-02 to 2023-11-24
# Create samples set from 2020-01-02 to 2023-11-27
# Create samples set from 2020-01-02 to 2023-11-28
# Create samples set from 2020-01-02 to 2023-11-29
# Create samples set from 2020-01-02 to 2023-11-30
# Create samples set from 2020-01-02 to 2023-12-01
# Create samples set from 2020-01-02 to 2023-12-04
# Create samples set from 2020-01-02 to 2023-12-05
# Create samples set from 2020-01-02 to 2023-12-06
# Create samples set from 2020-01-02 to 2023-12-07
# Create samples set from 2020-01-02 to 2023-12-08
# Create samples set from 2020-01-02 to 2023-12-11
# Create samples set from 2020-01-02 to 2023-12-12
# Create samples set from 2020-01-02 to 2023-12-13
# Create samples set from 2020-01-02 to 2023-12-14
# Create samples set from 2020-01-02 to 2023-12-15
# Create samples set from 2020-01-02 to 2023-12-18
# Create samples set from 2020-01-02 to 2023-12-19
# Create samples set from 2020-01-02 to 2023-12-20
# Create samples set from 2020-01-02 to 2023-12-21
# Create samples set from 2020-01-02 to 2023-12-22
# Create samples set from 2020-01-02 to 2023-12-25

# %%
my_df = df_fw_list[0]
my_df
# Out:
#             ds        y
# 0   2020-01-02  24177.0
# 1   2020-01-03  23890.0
# 2   2020-01-06  23508.0
# 3   2020-01-07  23412.0
# 4   2020-01-08  22170.0
# ..         ...      ...
# 903 2023-08-15  25100.0
# 904 2023-08-16  26200.0
# 905 2023-08-17  25900.0
# 906 2023-08-18  23900.0
# 907 2023-08-21  24000.0
#
# [908 rows x 2 columns]

# %% [markdown]
# ### Statistics analysis on stock before build AIMA models

# %% [markdown]
# We opt for the initial train from the dataset for model analysis. Since financial series, such as stocks, typically stabilize at the first different, there is no need for further ADF testing. Instead, our focus shifts to determining the appropriate parameters Q and P.

# %%
my_df = df_fw_list[0]

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import statsmodels.api as sm

# %%
fig, ax = plt.subplots(2,1,figsize=(15, 8))
chart = plot_acf(my_df['y'].diff().dropna(),lags=range(1,11),ax=ax[0],auto_ylims=True,color='#3d5afe',markerfacecoloralt='green',alpha=0.05)
chart = plot_pacf(my_df['y'].diff().dropna(),lags=range(1,11),ax=ax[1],auto_ylims=True,color='red',alpha=0.05)
plt.suptitle(f"ACF and PACF of 1st different {stock_target} stock", fontsize="x-large",fontweight="bold")
# Out:
# Text(0.5, 0.98, 'ACF and PACF of 1st different VGI stock')

# %%
acf, acf_ci = sm.tsa.acf(my_df['y'].diff().dropna(),nlags=10, alpha=0.05)
pacf, pacf_ci = sm.tsa.pacf(my_df['y'].diff().dropna(),nlags=10, alpha=0.05)

ac_table = pd.DataFrame(data={
    'lag': range(1,11),
    'acf_lower': acf_ci[1:,:1].reshape(10),
    'acf': acf[1:],
    'acf_upper': acf_ci[1:,1:].reshape(10),
    'pacf_lower': pacf_ci[1:,:1].reshape(10),
    'pacf': pacf[1:],
    'pacf_upper': pacf_ci[1:,1:].reshape(10),
})

ac_table
# Out:
#    lag  acf_lower       acf  acf_upper  pacf_lower      pacf  pacf_upper
# 0    1  -0.012842  0.052237   0.117317   -0.012785  0.052295    0.117374
# 1    2  -0.103507 -0.038250   0.027007   -0.106261 -0.041182    0.023898
# 2    3  -0.061131  0.004221   0.069573   -0.056566  0.008514    0.073593
# 3    4  -0.096593 -0.031240   0.034113   -0.098884 -0.033804    0.031275
# 4    5  -0.075548 -0.010132   0.055284   -0.071227 -0.006147    0.058933
# 5    6  -0.079999 -0.014577   0.050846   -0.081641 -0.016562    0.048518
# 6    7  -0.052019  0.013418   0.078855   -0.049975  0.015105    0.080184
# 7    8  -0.073729 -0.008281   0.057168   -0.077296 -0.012216    0.052863
# 8    9  -0.032841  0.032611   0.098064   -0.029884  0.035196    0.100275
# 9   10  -0.063777  0.001744   0.067266   -0.069275 -0.004195    0.060885

# %% [markdown]
# Now keep the lags level that have significant.

# %%
significant_acf_lags = [i + 1 for i, ci in enumerate(acf_ci[1:]) if (ci[0] < 0 and ci[1] < 0) or (ci[0] > 0 and ci[1] > 0)]
significant_pacf_lags = [i + 1 for i, ci in enumerate(pacf_ci[1:]) if (ci[0] < 0 and ci[1] < 0) or (ci[0] > 0 and ci[1] > 0)]

# %% [markdown]
# Hmm there is have no significant coeffient so just pick 3 lags that have largest absolute value

# %%
if len(significant_acf_lags) == 0 or len(significant_pacf_lags) == 0:
    significant_acf_lags = ac_table.loc[ac_table['acf'].abs().nlargest(3).index]['lag'].values
    significant_pacf_lags = ac_table.loc[ac_table['pacf'].abs().nlargest(3).index]['lag'].values

# %% [markdown]
# ### Hyper tunning parmaters for ARIMA model

# %% [markdown]
# We use our each sample data  split it in into train set have length by samples length minus 10 to train model and predict the once next day. After that we add the actual next day totrain set continue predict the next next day. Repeat this process until the length of the training set matches the total available training data, excluding one. Then we chose the model that have smallest RMSE.

# %%
from itertools import product
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
def build_model(train_data, p_list ,q_list):
      # Initial approximation of parameters
    Ps = p_list
    Qs = q_list
    d=[1]
    parameters = product(Ps,d,Qs)
    parameters_list = list(parameters)

    # Model Selection
    models = []
    for param in parameters_list:
        try:
            model = ARIMA(train_data, order=(param[0], param[1], param[2])).fit()
        except ValueError:
            print(parameters_list)
            continue
        models.append(model)
    return models

# %%
evaluate_table = pd.DataFrame(columns=['Model','Scenario','RMSE'])

# %%
choose_model_table = pd.DataFrame()
total_len = len(my_df['y'])
for idx in range(10):
  X_train = my_df['y'][:total_len - 10 + idx]
  X_test = my_df['y'][total_len - 10 + idx: total_len - 10 + idx+ 1]
  models = build_model(X_train, significant_acf_lags , significant_pacf_lags)
  for model in models:
     choose_model_table = pd.concat([choose_model_table,pd.DataFrame({
         'params': [(len(model.arparams),1,len(model.maparams))],
          # predict the next day
         'predict': np.array(model.forecast(steps=1)),
         'actual': X_test,
     })],axis=0)

# %%
df_model_eval = pd.DataFrame(choose_model_table.groupby('params').apply(lambda df: np.sqrt(mean_squared_error(df['actual'],df['predict']))))
df_model_eval.columns = ['rmse']
df_model_eval.reset_index(inplace=True)

# %%
len(df_model_eval['params'].unique())
# Out:
# 9

# %%
# Create a bar plot using plotly.graph_objects
fig = go.Figure()

fig.add_trace(go.Bar(
    # not conver have wire error 
    x=df_model_eval['params'].astype(str),
    y=df_model_eval['rmse'],
    text=df_model_eval['rmse'],
    hoverinfo='text',
    marker=dict(color='skyblue'),
))

# Customize the layout if needed
fig.update_layout(
    title=f'{stock_target} RMSE for Different ARIMA Parameter Sets',
    xaxis=dict(title='Parameter Sets', type='category'),
    yaxis=dict(title='RMSE'),
)

# Show the plot
fig.show()

# %% [markdown]
# We see the RMSE don't  too much different between the paramter sets around 800 dong, but ARIMA(2,1,2) still have smallest RMSE so will choose it for next stage (the backtest model stage).

# %%
(best_p,_,best_q) = df_model_eval.loc[df_model_eval['rmse'].idxmin()]['params']
(best_p,_,best_q)
# Out:
# (9, 1, 9)

# %% [markdown]
# ### Back testing on period from 22/8/203 to 26/8/2023

# %%
list_model = []

for df in df_fw_list:
    models = build_model(df['y'], [best_p], [best_q])
    for model in models:
        list_model.append(model)

# %%
results = pd.Series()
for  model in list_model:
     forecast = model.forecast(steps=1)      
     results =  pd.concat([results,forecast],axis=0)

# %%
y_actual = get_list_next_day_actual_test_range()
y_actual[['ds','y']] = y_actual[['time','close']]
y_actual = y_actual[['ds','y']]
y_actual['ds'] =  pd.to_datetime(y_actual['ds'])

# %%
compare_table = pd.DataFrame({
     'ds': y_actual['ds'],
     'y': y_actual['y'],
     'yhat': results.values
})
compare_table
# Out:
#            ds      y          yhat
# 0  2023-08-22  23700  24119.900837
# 1  2023-08-23  23500  23687.767711
# 2  2023-08-24  24000  23626.978828
# 3  2023-08-25  24200  24046.132187
# 4  2023-08-28  24700  24208.369335
# ..        ...    ...           ...
# 83 2023-12-20  25200  25053.463101
# 84 2023-12-21  25100  25218.463175
# 85 2023-12-22  25500  25106.217759
# 86 2023-12-25  25800  25617.769672
# 87 2023-12-26  25900  25754.673643
#
# [88 rows x 3 columns]

# %%
compare_table['y_change'] = compare_table['y'].diff()
compare_table['yhat_change'] = compare_table['yhat'].diff()
compare_table['y*yhat_chage'] = compare_table['y_change'] * compare_table['yhat_change']

# %%
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(compare_table['y'], compare_table['yhat']))
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Calculate correlation coefficient
correlation = compare_table['y'].corr(compare_table['yhat'])
print(f"Correlation Coefficient: {correlation}")

truth = []
for y_hat_change, y_change in zip(compare_table['yhat'].diff().dropna(),compare_table['y'].diff().dropna()):
    truth.append(1 if y_hat_change * y_change > 0 else 0)


print(f"Direction correction ratio: {np.sum(truth)/len(truth) * 100}")

r2 = r2_score(compare_table['y'], compare_table['yhat'])
print(f"R-squared (R²): {r2}")
# Out:
# Root Mean Squared Error (RMSE): 644.4618772074241
# Correlation Coefficient: 0.9121029074478676
# Direction correction ratio: 51.724137931034484
# R-squared (R²): 0.8246630924149754

# %%
df_mtr = pd.read_csv('./output/metrics-VGI.csv')
# remove old record
df_mtr = df_mtr[~(df_mtr['model'] == f'ARIMA{best_p,1,best_p}')]

df_mtr = pd.concat([df_mtr,
                    pd.DataFrame({
                     'model': [f'ARIMA{best_p,1,best_p}'],
                     'rmse': [rmse],
                     'correlation': [correlation],
                     'r-squared': [r2] })], axis=0)
df_mtr.to_csv('./output/metrics-VGI.csv',index=False)

df_mtr
# Out:
#             model         rmse  r-squared  correlation
# 1     LSTM(1,4,1)  1268.217233   0.321006     0.634703
# 2         Prophet  1493.068399  -0.001789     0.304553
# 3    Prophet-LSTM   776.421371   0.745508     0.869764
# 0  ARIMA(9, 1, 9)   644.461877   0.824663     0.912103

# %%
# Plotting with Plotly
fig = go.Figure()

# Plot yhat as a line
fig.add_trace(go.Scatter(x=compare_table['ds'], y=compare_table['yhat'], mode='lines+markers', name='yhat', line=dict(color='blue')))

# Plot y as points
fig.add_trace(go.Scatter(x=compare_table['ds'], y=compare_table['y'], mode='lines+markers', name='y', marker=dict(color='red', size=8)))

# Set layout
fig.update_layout(title=f'{stock_target} moving forward train and predict the next day with ARIMA{best_p,1,best_q}',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  showlegend=True)

# Show the plot
fig.show()

# %% [markdown]
# ### Hybrid ARIMA and LSTM

# %% [markdown]
# We use the predict and it's 3 lags result from ARIMA as input and the 2 lags t-1, t-2 of resid features to LSTM and the target variables still the stock price. The reason is that LSTM can capture some pattern ARIMA may be miss

# %%
from copy import deepcopy as dc

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset):
  def __init__(self, X, y):
    self.X = X
    self.y = y

  def __len__(self):
    return len(self.X)

  def __getitem__(self, i):
    return self.X[i], self.y[i]

# %%
class LSTM(nn.Module):
  def __init__(self, input_size, hidden_size, num_stacked_layers):
    super().__init__()
    self.hidden_size = hidden_size
    self.num_stacked_layers = num_stacked_layers
    self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers,
                        batch_first = True)
    self.fc = nn.Linear(hidden_size, 1)

  def forward(self, x):
    batch_size = x.size(0)
    h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
    c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
    out, _ = self.lstm(x, (h0, c0))
    out = self.fc(out[:, -1, :])
    return out

# %%
def create_predict_list():
     predict_list = []
     for  model, df  in zip(list_model, df_fw_list):
      predict = model.get_prediction().predicted_mean
      df = dc(df)
      df['yhat'] = predict
      df['resid'] = model.resid
      predict_list.append(df)
     
     return predict_list

# %%
df_predict_list = create_predict_list()

# %%
df_predict_list[0]
# Out:
#             ds        y          yhat         resid
# 0   2020-01-02  24177.0      0.000000  24177.000000
# 1   2020-01-03  23890.0  24612.896423   -722.896423
# 2   2020-01-06  23508.0  23319.967618    188.032382
# 3   2020-01-07  23412.0  23543.451130   -131.451130
# 4   2020-01-08  22170.0  22994.146537   -824.146537
# ..         ...      ...           ...           ...
# 903 2023-08-15  25100.0  25243.385935   -143.385935
# 904 2023-08-16  26200.0  25061.637078   1138.362922
# 905 2023-08-17  25900.0  26178.905773   -278.905773
# 906 2023-08-18  23900.0  25820.735282  -1920.735282
# 907 2023-08-21  24000.0  23817.657934    182.342066
#
# [908 rows x 4 columns]

# %%
LSTM_loop_back=3
LSTM_lstm_input_cols = ['y','yhat']
LSTM_resid_loop_back = 2

shifted_df_LSTM_list = []

def prepare_dataframe_grach_for_lstm(df, n_steps, resid_loop_back):
  df = dc(df)[LSTM_lstm_input_cols]
  for i in range(1, n_steps + 1):
    df[f'yhat(t-{i})'] = df['yhat'].shift(i)
  for i in range(1,resid_loop_back+1):
      df[f'resid(t-{i})'] = (df['y'] - df['yhat']).shift(i)

  return df

for df in df_predict_list:
   shifted_df  = prepare_dataframe_grach_for_lstm(df,LSTM_loop_back,LSTM_resid_loop_back)
   shifted_df_LSTM_list.append(shifted_df)

# %%
shifted_df_LSTM_list[0]
# Out:
#            y          yhat     yhat(t-1)     yhat(t-2)     yhat(t-3)  \
# 0    24177.0      0.000000           NaN           NaN           NaN
# 1    23890.0  24612.896423      0.000000           NaN           NaN
# 2    23508.0  23319.967618  24612.896423      0.000000           NaN
# 3    23412.0  23543.451130  23319.967618  24612.896423      0.000000
# 4    22170.0  22994.146537  23543.451130  23319.967618  24612.896423
# ..       ...           ...           ...           ...           ...
# 903  25100.0  25243.385935  25100.717864  24898.963309  25460.263064
# 904  26200.0  25061.637078  25243.385935  25100.717864  24898.963309
# 905  25900.0  26178.905773  25061.637078  25243.385935  25100.717864
# 906  23900.0  25820.735282  26178.905773  25061.637078  25243.385935
# 907  24000.0  23817.657934  25820.735282  26178.905773  25061.637078
#
#        resid(t-1)    resid(t-2)
# 0             NaN           NaN
# 1    24177.000000           NaN
# 2     -722.896423  24177.000000
# 3      188.032382   -722.896423
# 4     -131.451130    188.032382
# ..            ...           ...
# 903    199.282136    201.036691
# 904   -143.385935    199.282136
# 905   1138.362922   -143.385935
# 906   -278.905773   1138.362922
# 907  -1920.735282   -278.905773
#
# [908 rows x 7 columns]

# %%
scaler_LSTM_input_list, scaler_LSTM_list = multi_scaler_df([df_shifted.dropna() for df_shifted in shifted_df_LSTM_list])

# %%
scaler_LSTM_input_list[0]
# Out:
# array([[0.19706667, 0.1921102 , 0.18457075, ..., 0.        , 0.53607548,
#         0.4259898 ],
#        [0.15566667, 0.17357883, 0.1921102 , ..., 0.51826639, 0.49746592,
#         0.53607548],
#        [0.15566667, 0.1446826 , 0.17357883, ..., 0.49104158, 0.41375373,
#         0.49746592],
#        ...,
#        [0.28      , 0.28102004, 0.2433278 , ..., 0.5285383 , 0.65092286,
#         0.4960236 ],
#        [0.21333333, 0.26893678, 0.28102004, ..., 0.53154242, 0.47964604,
#         0.65092286],
#        [0.21666667, 0.20136085, 0.26893678, ..., 0.52771539, 0.28123106,
#         0.47964604]])

# %%
X_list = []
y_list = []

for shifted_df_scaler in scaler_LSTM_input_list:
    X = shifted_df_scaler[:, 1:]
    y = shifted_df_scaler[:, 0:1]
    X_list.append(X)
    y_list.append(y)

# %%
X_train_list = [X_train.reshape((-1, 1, LSTM_loop_back+ 1 + LSTM_resid_loop_back)) for X_train in X_list]
y_train_list =  [y_train.reshape((-1, 1)) for y_train in y_list]

# %%
X_train_list = [torch.tensor(X_train).float() for X_train in X_train_list]
y_train_list = [torch.tensor(y_train).float() for y_train in y_train_list]

X_train_list[0].shape, y_train_list[0].shape
# Out:
# (torch.Size([905, 1, 6]), torch.Size([905, 1]))

# %%
train_dataset_list = [TimeSeriesDataset(X_train, y_train) for X_train, y_train in zip(X_train_list,y_train_list)]

# %%
from torch.utils.data import DataLoader
batch_size = 12

train_loader_list = [DataLoader(train_dataset, batch_size = batch_size, shuffle = True) for train_dataset in train_dataset_list ]

# %%
train_loader_list[0]

# %% [markdown]
# #### Init LSTM model 6,4,1

# %%
list_LSTM_model = []

for i in range(len(train_loader_list)):
  m = LSTM(6, 4, 1) #1,4,1 19:30
  m.to(device)
  list_LSTM_model.append(m)

list_LSTM_model[0]
# Out:
# LSTM(
#   (lstm): LSTM(6, 4, batch_first=True)
#   (fc): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
learning_rate = 0.001
num_epochs = 20
loss_function = nn.MSELoss()

def train_one_epoch(model,train_loader,epoch):
  optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)
  model.train(True)
  print(f'Epoch: {epoch + 1}')
  running_loss = 0.0

  for batch_index, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)

    output = model(x_batch)
    loss = loss_function(output, y_batch)
    running_loss += loss.item()

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if batch_index % 10 == 0: # print every 10 batches
        avg_loss_across_batches = running_loss / 1
        print('Batch {0}, Loss: {1:.3f}'.format(batch_index+1,
                                              avg_loss_across_batches))
        running_loss = 0.0
  print()
  return running_loss

# %%
for model, train_loader in zip(list_LSTM_model,train_loader_list):
  for epoch in range(num_epochs):
    train_one_epoch(model=model,train_loader=train_loader,epoch=epoch)
# Out:
# Epoch: 1
# Batch 1, Loss: 0.592
# Batch 11, Loss: 6.786
# Batch 21, Loss: 6.321
# Batch 31, Loss: 6.240
# Batch 41, Loss: 5.159
# Batch 51, Loss: 4.346
# Batch 61, Loss: 4.655
# Batch 71, Loss: 3.550
#
# Epoch: 2
# Batch 1, Loss: 0.392
# Batch 11, Loss: 3.211
# Batch 21, Loss: 3.205
# Batch 31, Loss: 3.025
# Batch 41, Loss: 2.499
# Batch 51, Loss: 2.300
# Batch 61, Loss: 2.018
# Batch 71, Loss: 1.736
#
# Epoch: 3
# Batch 1, Loss: 0.173
# Batch 11, Loss: 1.472
# Batch 21, Loss: 1.330
# Batch 31, Loss: 0.824
# Batch 41, Loss: 0.938
# Batch 51, Loss: 0.623
# Batch 61, Loss: 0.658
# Batch 71, Loss: 0.408
#
# Epoch: 4
# Batch 1, Loss: 0.011
# Batch 11, Loss: 0.346
# Batch 21, Loss: 0.217
# Batch 31, Loss: 0.188
# Batch 41, Loss: 0.217
# Batch 51, Loss: 0.208
# Batch 61, Loss: 0.164
# Batch 71, Loss: 0.130
#
# Epoch: 5
# Batch 1, Loss: 0.009
# Batch 11, Loss: 0.190
# Batch 21, Loss: 0.132
# Batch 31, Loss: 0.131
# Batch 41, Loss: 0.087
# Batch 51, Loss: 0.090
# Batch 61, Loss: 0.108
# Batch 71, Loss: 0.095
#
# Epoch: 6
# Batch 1, Loss: 0.007
# Batch 11, Loss: 0.099
# Batch 21, Loss: 0.059
# Batch 31, Loss: 0.043
# Batch 41, Loss: 0.053
# Batch 51, Loss: 0.043
# Batch 61, Loss: 0.043
# Batch 71, Loss: 0.044
#
# Epoch: 7
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.027
# Batch 21, Loss: 0.025
# Batch 31, Loss: 0.020
# Batch 41, Loss: 0.035
# Batch 51, Loss: 0.031
# Batch 61, Loss: 0.026
# Batch 71, Loss: 0.022
#
# Epoch: 8
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.020
# Batch 21, Loss: 0.027
# Batch 31, Loss: 0.022
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.020
# Batch 61, Loss: 0.018
# Batch 71, Loss: 0.021
#
# Epoch: 9
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.020
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.022
# Batch 41, Loss: 0.021
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.016
# Batch 71, Loss: 0.017
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.019
# Batch 51, Loss: 0.017
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.015
#
# Epoch: 11
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.015
# Batch 31, Loss: 0.016
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.016
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.011
#
# Epoch: 12
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.018
# Batch 71, Loss: 0.012
#
# Epoch: 13
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.011
#
# Epoch: 14
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.013
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.011
#
# Epoch: 16
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.011
#
# Epoch: 17
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.011
#
# Epoch: 18
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.011
#
# Epoch: 19
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.006
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.007
#
# Epoch: 20
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.006
#
# Epoch: 1
# Batch 1, Loss: 0.365
# Batch 11, Loss: 3.037
# Batch 21, Loss: 3.013
# Batch 31, Loss: 2.483
# Batch 41, Loss: 2.315
# Batch 51, Loss: 1.740
# Batch 61, Loss: 1.702
# Batch 71, Loss: 1.738
#
# Epoch: 2
# Batch 1, Loss: 0.220
# Batch 11, Loss: 1.047
# Batch 21, Loss: 0.949
# Batch 31, Loss: 0.938
# Batch 41, Loss: 0.771
# Batch 51, Loss: 0.507
# Batch 61, Loss: 0.393
# Batch 71, Loss: 0.376
#
# Epoch: 3
# Batch 1, Loss: 0.010
# Batch 11, Loss: 0.366
# Batch 21, Loss: 0.218
# Batch 31, Loss: 0.251
# Batch 41, Loss: 0.240
# Batch 51, Loss: 0.244
# Batch 61, Loss: 0.201
# Batch 71, Loss: 0.154
#
# Epoch: 4
# Batch 1, Loss: 0.017
# Batch 11, Loss: 0.176
# Batch 21, Loss: 0.120
# Batch 31, Loss: 0.167
# Batch 41, Loss: 0.165
# Batch 51, Loss: 0.138
# Batch 61, Loss: 0.115
# Batch 71, Loss: 0.105
#
# Epoch: 5
# Batch 1, Loss: 0.006
# Batch 11, Loss: 0.083
# Batch 21, Loss: 0.068
# Batch 31, Loss: 0.067
# Batch 41, Loss: 0.060
# Batch 51, Loss: 0.043
# Batch 61, Loss: 0.054
# Batch 71, Loss: 0.034
#
# Epoch: 6
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.026
# Batch 21, Loss: 0.020
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.015
#
# Epoch: 7
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.013
#
# Epoch: 8
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.007
#
# Epoch: 9
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 11
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.013
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.006
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.006
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.007
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.007
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.010
#
# Epoch: 16
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 18
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.012
#
# Epoch: 19
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.012
#
# Epoch: 1
# Batch 1, Loss: 0.253
# Batch 11, Loss: 2.041
# Batch 21, Loss: 1.768
# Batch 31, Loss: 1.403
# Batch 41, Loss: 1.570
# Batch 51, Loss: 1.301
# Batch 61, Loss: 0.842
# Batch 71, Loss: 1.015
#
# Epoch: 2
# Batch 1, Loss: 0.121
# Batch 11, Loss: 0.635
# Batch 21, Loss: 0.635
# Batch 31, Loss: 0.405
# Batch 41, Loss: 0.389
# Batch 51, Loss: 0.331
# Batch 61, Loss: 0.238
# Batch 71, Loss: 0.236
#
# Epoch: 3
# Batch 1, Loss: 0.031
# Batch 11, Loss: 0.211
# Batch 21, Loss: 0.196
# Batch 31, Loss: 0.177
# Batch 41, Loss: 0.154
# Batch 51, Loss: 0.162
# Batch 61, Loss: 0.139
# Batch 71, Loss: 0.125
#
# Epoch: 4
# Batch 1, Loss: 0.015
# Batch 11, Loss: 0.118
# Batch 21, Loss: 0.110
# Batch 31, Loss: 0.070
# Batch 41, Loss: 0.095
# Batch 51, Loss: 0.070
# Batch 61, Loss: 0.080
# Batch 71, Loss: 0.067
#
# Epoch: 5
# Batch 1, Loss: 0.005
# Batch 11, Loss: 0.042
# Batch 21, Loss: 0.039
# Batch 31, Loss: 0.039
# Batch 41, Loss: 0.026
# Batch 51, Loss: 0.034
# Batch 61, Loss: 0.025
# Batch 71, Loss: 0.025
#
# Epoch: 6
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.022
# Batch 21, Loss: 0.020
# Batch 31, Loss: 0.020
# Batch 41, Loss: 0.019
# Batch 51, Loss: 0.021
# Batch 61, Loss: 0.022
# Batch 71, Loss: 0.016
#
# Epoch: 7
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.020
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.016
# Batch 41, Loss: 0.025
# Batch 51, Loss: 0.015
# Batch 61, Loss: 0.022
# Batch 71, Loss: 0.018
#
# Epoch: 8
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.015
# Batch 31, Loss: 0.021
# Batch 41, Loss: 0.020
# Batch 51, Loss: 0.018
# Batch 61, Loss: 0.018
# Batch 71, Loss: 0.015
#
# Epoch: 9
# Batch 1, Loss: 0.006
# Batch 11, Loss: 0.017
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.017
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.016
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.014
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.018
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.021
#
# Epoch: 11
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.025
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.008
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.019
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.014
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.015
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.017
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 14
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.014
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.007
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.012
#
# Epoch: 16
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.013
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.015
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.012
#
# Epoch: 19
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.007
#
# Epoch: 20
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 1
# Batch 1, Loss: 0.516
# Batch 11, Loss: 4.319
# Batch 21, Loss: 4.137
# Batch 31, Loss: 3.721
# Batch 41, Loss: 3.613
# Batch 51, Loss: 3.443
# Batch 61, Loss: 3.353
# Batch 71, Loss: 2.694
#
# Epoch: 2
# Batch 1, Loss: 0.261
# Batch 11, Loss: 2.178
# Batch 21, Loss: 1.810
# Batch 31, Loss: 1.751
# Batch 41, Loss: 1.289
# Batch 51, Loss: 1.316
# Batch 61, Loss: 1.038
# Batch 71, Loss: 0.864
#
# Epoch: 3
# Batch 1, Loss: 0.102
# Batch 11, Loss: 0.576
# Batch 21, Loss: 0.370
# Batch 31, Loss: 0.350
# Batch 41, Loss: 0.286
# Batch 51, Loss: 0.277
# Batch 61, Loss: 0.261
# Batch 71, Loss: 0.199
#
# Epoch: 4
# Batch 1, Loss: 0.027
# Batch 11, Loss: 0.194
# Batch 21, Loss: 0.180
# Batch 31, Loss: 0.200
# Batch 41, Loss: 0.152
# Batch 51, Loss: 0.150
# Batch 61, Loss: 0.146
# Batch 71, Loss: 0.146
#
# Epoch: 5
# Batch 1, Loss: 0.004
# Batch 11, Loss: 0.135
# Batch 21, Loss: 0.134
# Batch 31, Loss: 0.098
# Batch 41, Loss: 0.124
# Batch 51, Loss: 0.089
# Batch 61, Loss: 0.076
# Batch 71, Loss: 0.076
#
# Epoch: 6
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.093
# Batch 21, Loss: 0.050
# Batch 31, Loss: 0.063
# Batch 41, Loss: 0.045
# Batch 51, Loss: 0.049
# Batch 61, Loss: 0.050
# Batch 71, Loss: 0.040
#
# Epoch: 7
# Batch 1, Loss: 0.011
# Batch 11, Loss: 0.029
# Batch 21, Loss: 0.023
# Batch 31, Loss: 0.037
# Batch 41, Loss: 0.031
# Batch 51, Loss: 0.029
# Batch 61, Loss: 0.031
# Batch 71, Loss: 0.022
#
# Epoch: 8
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.017
# Batch 21, Loss: 0.034
# Batch 31, Loss: 0.021
# Batch 41, Loss: 0.020
# Batch 51, Loss: 0.030
# Batch 61, Loss: 0.029
# Batch 71, Loss: 0.018
#
# Epoch: 9
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.025
# Batch 21, Loss: 0.018
# Batch 31, Loss: 0.023
# Batch 41, Loss: 0.018
# Batch 51, Loss: 0.021
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.028
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.031
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.018
# Batch 41, Loss: 0.021
# Batch 51, Loss: 0.022
# Batch 61, Loss: 0.017
# Batch 71, Loss: 0.016
#
# Epoch: 11
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.019
# Batch 21, Loss: 0.020
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.020
# Batch 51, Loss: 0.017
# Batch 61, Loss: 0.019
# Batch 71, Loss: 0.012
#
# Epoch: 12
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.018
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.018
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.017
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.020
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.018
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.017
# Batch 71, Loss: 0.013
#
# Epoch: 14
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.018
#
# Epoch: 15
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.017
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.018
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.015
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.015
#
# Epoch: 16
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.017
# Batch 71, Loss: 0.015
#
# Epoch: 17
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.007
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.006
# Batch 71, Loss: 0.015
#
# Epoch: 19
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.012
#
# Epoch: 20
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.015
#
# Epoch: 1
# Batch 1, Loss: 0.031
# Batch 11, Loss: 0.360
# Batch 21, Loss: 0.421
# Batch 31, Loss: 0.344
# Batch 41, Loss: 0.326
# Batch 51, Loss: 0.324
# Batch 61, Loss: 0.365
# Batch 71, Loss: 0.369
#
# Epoch: 2
# Batch 1, Loss: 0.023
# Batch 11, Loss: 0.272
# Batch 21, Loss: 0.306
# Batch 31, Loss: 0.263
# Batch 41, Loss: 0.293
# Batch 51, Loss: 0.311
# Batch 61, Loss: 0.273
# Batch 71, Loss: 0.184
#
# Epoch: 3
# Batch 1, Loss: 0.043
# Batch 11, Loss: 0.209
# Batch 21, Loss: 0.179
# Batch 31, Loss: 0.182
# Batch 41, Loss: 0.211
# Batch 51, Loss: 0.200
# Batch 61, Loss: 0.168
# Batch 71, Loss: 0.173
#
# Epoch: 4
# Batch 1, Loss: 0.009
# Batch 11, Loss: 0.155
# Batch 21, Loss: 0.124
# Batch 31, Loss: 0.155
# Batch 41, Loss: 0.110
# Batch 51, Loss: 0.082
# Batch 61, Loss: 0.106
# Batch 71, Loss: 0.101
#
# Epoch: 5
# Batch 1, Loss: 0.006
# Batch 11, Loss: 0.083
# Batch 21, Loss: 0.083
# Batch 31, Loss: 0.064
# Batch 41, Loss: 0.054
# Batch 51, Loss: 0.065
# Batch 61, Loss: 0.039
# Batch 71, Loss: 0.053
#
# Epoch: 6
# Batch 1, Loss: 0.006
# Batch 11, Loss: 0.037
# Batch 21, Loss: 0.039
# Batch 31, Loss: 0.031
# Batch 41, Loss: 0.038
# Batch 51, Loss: 0.033
# Batch 61, Loss: 0.030
# Batch 71, Loss: 0.025
#
# Epoch: 7
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.023
# Batch 21, Loss: 0.036
# Batch 31, Loss: 0.028
# Batch 41, Loss: 0.029
# Batch 51, Loss: 0.026
# Batch 61, Loss: 0.025
# Batch 71, Loss: 0.024
#
# Epoch: 8
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.022
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.022
# Batch 41, Loss: 0.023
# Batch 51, Loss: 0.034
# Batch 61, Loss: 0.025
# Batch 71, Loss: 0.016
#
# Epoch: 9
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.015
# Batch 31, Loss: 0.018
# Batch 41, Loss: 0.019
# Batch 51, Loss: 0.022
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.022
#
# Epoch: 10
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.018
# Batch 21, Loss: 0.022
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.020
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.011
#
# Epoch: 11
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.015
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.016
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.017
# Batch 71, Loss: 0.014
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.013
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.013
#
# Epoch: 14
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.008
#
# Epoch: 15
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.014
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.011
#
# Epoch: 16
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 17
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.009
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.011
#
# Epoch: 19
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 20
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.006
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 1
# Batch 1, Loss: 0.337
# Batch 11, Loss: 3.683
# Batch 21, Loss: 3.864
# Batch 31, Loss: 3.586
# Batch 41, Loss: 3.529
# Batch 51, Loss: 3.388
# Batch 61, Loss: 3.039
# Batch 71, Loss: 2.536
#
# Epoch: 2
# Batch 1, Loss: 0.279
# Batch 11, Loss: 2.643
# Batch 21, Loss: 2.352
# Batch 31, Loss: 1.866
# Batch 41, Loss: 1.844
# Batch 51, Loss: 1.844
# Batch 61, Loss: 1.546
# Batch 71, Loss: 1.356
#
# Epoch: 3
# Batch 1, Loss: 0.130
# Batch 11, Loss: 1.161
# Batch 21, Loss: 0.910
# Batch 31, Loss: 0.682
# Batch 41, Loss: 0.605
# Batch 51, Loss: 0.740
# Batch 61, Loss: 0.498
# Batch 71, Loss: 0.443
#
# Epoch: 4
# Batch 1, Loss: 0.030
# Batch 11, Loss: 0.274
# Batch 21, Loss: 0.405
# Batch 31, Loss: 0.301
# Batch 41, Loss: 0.210
# Batch 51, Loss: 0.215
# Batch 61, Loss: 0.193
# Batch 71, Loss: 0.205
#
# Epoch: 5
# Batch 1, Loss: 0.016
# Batch 11, Loss: 0.218
# Batch 21, Loss: 0.175
# Batch 31, Loss: 0.169
# Batch 41, Loss: 0.179
# Batch 51, Loss: 0.146
# Batch 61, Loss: 0.159
# Batch 71, Loss: 0.144
#
# Epoch: 6
# Batch 1, Loss: 0.014
# Batch 11, Loss: 0.146
# Batch 21, Loss: 0.112
# Batch 31, Loss: 0.092
# Batch 41, Loss: 0.078
# Batch 51, Loss: 0.076
# Batch 61, Loss: 0.085
# Batch 71, Loss: 0.057
#
# Epoch: 7
# Batch 1, Loss: 0.011
# Batch 11, Loss: 0.052
# Batch 21, Loss: 0.038
# Batch 31, Loss: 0.038
# Batch 41, Loss: 0.044
# Batch 51, Loss: 0.036
# Batch 61, Loss: 0.032
# Batch 71, Loss: 0.029
#
# Epoch: 8
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.021
# Batch 21, Loss: 0.029
# Batch 31, Loss: 0.021
# Batch 41, Loss: 0.028
# Batch 51, Loss: 0.016
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.015
#
# Epoch: 9
# Batch 1, Loss: 0.004
# Batch 11, Loss: 0.017
# Batch 21, Loss: 0.017
# Batch 31, Loss: 0.016
# Batch 41, Loss: 0.023
# Batch 51, Loss: 0.022
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.012
#
# Epoch: 10
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.018
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.018
# Batch 51, Loss: 0.016
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.018
#
# Epoch: 11
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.019
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.016
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.017
# Batch 61, Loss: 0.016
# Batch 71, Loss: 0.015
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.014
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.020
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.015
# Batch 61, Loss: 0.018
# Batch 71, Loss: 0.009
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.022
# Batch 71, Loss: 0.013
#
# Epoch: 14
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.018
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.011
#
# Epoch: 16
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.017
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.013
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.008
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.014
#
# Epoch: 19
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.007
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.011
#
# Epoch: 20
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.010
#
# Epoch: 1
# Batch 1, Loss: 0.615
# Batch 11, Loss: 4.760
# Batch 21, Loss: 4.915
# Batch 31, Loss: 4.106
# Batch 41, Loss: 3.889
# Batch 51, Loss: 3.519
# Batch 61, Loss: 3.250
# Batch 71, Loss: 2.726
#
# Epoch: 2
# Batch 1, Loss: 0.267
# Batch 11, Loss: 2.144
# Batch 21, Loss: 1.834
# Batch 31, Loss: 1.584
# Batch 41, Loss: 1.089
# Batch 51, Loss: 1.029
# Batch 61, Loss: 0.857
# Batch 71, Loss: 0.536
#
# Epoch: 3
# Batch 1, Loss: 0.051
# Batch 11, Loss: 0.335
# Batch 21, Loss: 0.259
# Batch 31, Loss: 0.167
# Batch 41, Loss: 0.193
# Batch 51, Loss: 0.137
# Batch 61, Loss: 0.113
# Batch 71, Loss: 0.122
#
# Epoch: 4
# Batch 1, Loss: 0.013
# Batch 11, Loss: 0.116
# Batch 21, Loss: 0.086
# Batch 31, Loss: 0.088
# Batch 41, Loss: 0.090
# Batch 51, Loss: 0.090
# Batch 61, Loss: 0.072
# Batch 71, Loss: 0.060
#
# Epoch: 5
# Batch 1, Loss: 0.009
# Batch 11, Loss: 0.059
# Batch 21, Loss: 0.048
# Batch 31, Loss: 0.036
# Batch 41, Loss: 0.038
# Batch 51, Loss: 0.033
# Batch 61, Loss: 0.029
# Batch 71, Loss: 0.025
#
# Epoch: 6
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.028
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.019
# Batch 41, Loss: 0.016
# Batch 51, Loss: 0.020
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.015
#
# Epoch: 7
# Batch 1, Loss: 0.004
# Batch 11, Loss: 0.018
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.016
#
# Epoch: 8
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.018
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.017
# Batch 61, Loss: 0.016
# Batch 71, Loss: 0.010
#
# Epoch: 9
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.021
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.015
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.010
#
# Epoch: 11
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.019
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.011
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.015
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 13
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.011
#
# Epoch: 14
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.009
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.013
#
# Epoch: 16
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.006
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.013
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 19
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.006
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.012
#
# Epoch: 20
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.009
#
# Epoch: 1
# Batch 1, Loss: 0.565
# Batch 11, Loss: 5.852
# Batch 21, Loss: 4.855
# Batch 31, Loss: 4.743
# Batch 41, Loss: 4.211
# Batch 51, Loss: 3.399
# Batch 61, Loss: 3.072
# Batch 71, Loss: 2.728
#
# Epoch: 2
# Batch 1, Loss: 0.261
# Batch 11, Loss: 2.345
# Batch 21, Loss: 1.652
# Batch 31, Loss: 1.508
# Batch 41, Loss: 1.236
# Batch 51, Loss: 0.911
# Batch 61, Loss: 0.857
# Batch 71, Loss: 0.628
#
# Epoch: 3
# Batch 1, Loss: 0.046
# Batch 11, Loss: 0.425
# Batch 21, Loss: 0.248
# Batch 31, Loss: 0.250
# Batch 41, Loss: 0.174
# Batch 51, Loss: 0.189
# Batch 61, Loss: 0.169
# Batch 71, Loss: 0.187
#
# Epoch: 4
# Batch 1, Loss: 0.009
# Batch 11, Loss: 0.179
# Batch 21, Loss: 0.168
# Batch 31, Loss: 0.115
# Batch 41, Loss: 0.129
# Batch 51, Loss: 0.148
# Batch 61, Loss: 0.085
# Batch 71, Loss: 0.098
#
# Epoch: 5
# Batch 1, Loss: 0.016
# Batch 11, Loss: 0.096
# Batch 21, Loss: 0.058
# Batch 31, Loss: 0.075
# Batch 41, Loss: 0.065
# Batch 51, Loss: 0.057
# Batch 61, Loss: 0.059
# Batch 71, Loss: 0.046
#
# Epoch: 6
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.040
# Batch 21, Loss: 0.038
# Batch 31, Loss: 0.030
# Batch 41, Loss: 0.023
# Batch 51, Loss: 0.020
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.009
#
# Epoch: 7
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.016
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.013
#
# Epoch: 8
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.014
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.014
#
# Epoch: 9
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.014
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.009
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.010
#
# Epoch: 11
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.008
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.011
#
# Epoch: 13
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.007
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.007
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.006
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.010
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.010
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.008
#
# Epoch: 19
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.005
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.011
#
# Epoch: 20
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.012
#
# Epoch: 1
# Batch 1, Loss: 0.532
# Batch 11, Loss: 6.057
# Batch 21, Loss: 5.457
# Batch 31, Loss: 4.446
# Batch 41, Loss: 4.572
# Batch 51, Loss: 4.490
# Batch 61, Loss: 4.105
# Batch 71, Loss: 4.556
#
# Epoch: 2
# Batch 1, Loss: 0.342
# Batch 11, Loss: 3.105
# Batch 21, Loss: 3.078
# Batch 31, Loss: 2.847
# Batch 41, Loss: 2.788
# Batch 51, Loss: 2.110
# Batch 61, Loss: 2.196
# Batch 71, Loss: 1.917
#
# Epoch: 3
# Batch 1, Loss: 0.176
# Batch 11, Loss: 1.334
# Batch 21, Loss: 1.104
# Batch 31, Loss: 0.758
# Batch 41, Loss: 0.735
# Batch 51, Loss: 0.597
# Batch 61, Loss: 0.539
# Batch 71, Loss: 0.490
#
# Epoch: 4
# Batch 1, Loss: 0.041
# Batch 11, Loss: 0.204
# Batch 21, Loss: 0.199
# Batch 31, Loss: 0.207
# Batch 41, Loss: 0.192
# Batch 51, Loss: 0.173
# Batch 61, Loss: 0.175
# Batch 71, Loss: 0.144
#
# Epoch: 5
# Batch 1, Loss: 0.013
# Batch 11, Loss: 0.146
# Batch 21, Loss: 0.170
# Batch 31, Loss: 0.115
# Batch 41, Loss: 0.133
# Batch 51, Loss: 0.106
# Batch 61, Loss: 0.079
# Batch 71, Loss: 0.119
#
# Epoch: 6
# Batch 1, Loss: 0.008
# Batch 11, Loss: 0.088
# Batch 21, Loss: 0.072
# Batch 31, Loss: 0.068
# Batch 41, Loss: 0.062
# Batch 51, Loss: 0.070
# Batch 61, Loss: 0.053
# Batch 71, Loss: 0.046
#
# Epoch: 7
# Batch 1, Loss: 0.004
# Batch 11, Loss: 0.045
# Batch 21, Loss: 0.033
# Batch 31, Loss: 0.028
# Batch 41, Loss: 0.017
# Batch 51, Loss: 0.025
# Batch 61, Loss: 0.024
# Batch 71, Loss: 0.026
#
# Epoch: 8
# Batch 1, Loss: 0.004
# Batch 11, Loss: 0.014
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.019
# Batch 51, Loss: 0.015
# Batch 61, Loss: 0.016
# Batch 71, Loss: 0.011
#
# Epoch: 9
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.017
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.015
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.016
# Batch 71, Loss: 0.012
#
# Epoch: 11
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.016
# Batch 61, Loss: 0.017
# Batch 71, Loss: 0.009
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.016
# Batch 71, Loss: 0.013
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.011
#
# Epoch: 14
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.019
#
# Epoch: 15
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.012
#
# Epoch: 16
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.009
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.014
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.006
#
# Epoch: 19
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.015
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.006
#
# Epoch: 20
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.011
#
# Epoch: 1
# Batch 1, Loss: 0.605
# Batch 11, Loss: 6.273
# Batch 21, Loss: 6.139
# Batch 31, Loss: 5.478
# Batch 41, Loss: 5.001
# Batch 51, Loss: 4.317
# Batch 61, Loss: 4.406
# Batch 71, Loss: 3.958
#
# Epoch: 2
# Batch 1, Loss: 0.340
# Batch 11, Loss: 3.185
# Batch 21, Loss: 2.818
# Batch 31, Loss: 2.172
# Batch 41, Loss: 2.397
# Batch 51, Loss: 1.934
# Batch 61, Loss: 1.699
# Batch 71, Loss: 1.457
#
# Epoch: 3
# Batch 1, Loss: 0.130
# Batch 11, Loss: 1.089
# Batch 21, Loss: 0.812
# Batch 31, Loss: 0.582
# Batch 41, Loss: 0.473
# Batch 51, Loss: 0.436
# Batch 61, Loss: 0.292
# Batch 71, Loss: 0.276
#
# Epoch: 4
# Batch 1, Loss: 0.010
# Batch 11, Loss: 0.180
# Batch 21, Loss: 0.176
# Batch 31, Loss: 0.138
# Batch 41, Loss: 0.132
# Batch 51, Loss: 0.153
# Batch 61, Loss: 0.122
# Batch 71, Loss: 0.133
#
# Epoch: 5
# Batch 1, Loss: 0.007
# Batch 11, Loss: 0.072
# Batch 21, Loss: 0.101
# Batch 31, Loss: 0.093
# Batch 41, Loss: 0.069
# Batch 51, Loss: 0.059
# Batch 61, Loss: 0.055
# Batch 71, Loss: 0.068
#
# Epoch: 6
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.045
# Batch 21, Loss: 0.047
# Batch 31, Loss: 0.028
# Batch 41, Loss: 0.027
# Batch 51, Loss: 0.022
# Batch 61, Loss: 0.019
# Batch 71, Loss: 0.018
#
# Epoch: 7
# Batch 1, Loss: 0.004
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.021
# Batch 41, Loss: 0.020
# Batch 51, Loss: 0.019
# Batch 61, Loss: 0.016
# Batch 71, Loss: 0.017
#
# Epoch: 8
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.018
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.022
# Batch 41, Loss: 0.018
# Batch 51, Loss: 0.016
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.014
#
# Epoch: 9
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.015
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.018
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.016
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.016
# Batch 71, Loss: 0.019
#
# Epoch: 11
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.017
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.013
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.016
#
# Epoch: 13
# Batch 1, Loss: 0.005
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.012
#
# Epoch: 14
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.011
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.013
#
# Epoch: 16
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.014
#
# Epoch: 17
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.010
#
# Epoch: 18
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.012
#
# Epoch: 19
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.009
#
# Epoch: 20
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.015
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.006
# Batch 71, Loss: 0.011
#
# Epoch: 1
# Batch 1, Loss: 0.080
# Batch 11, Loss: 1.083
# Batch 21, Loss: 0.969
# Batch 31, Loss: 0.684
# Batch 41, Loss: 0.722
# Batch 51, Loss: 0.665
# Batch 61, Loss: 0.607
# Batch 71, Loss: 0.438
#
# Epoch: 2
# Batch 1, Loss: 0.022
# Batch 11, Loss: 0.398
# Batch 21, Loss: 0.431
# Batch 31, Loss: 0.388
# Batch 41, Loss: 0.321
# Batch 51, Loss: 0.343
# Batch 61, Loss: 0.266
# Batch 71, Loss: 0.214
#
# Epoch: 3
# Batch 1, Loss: 0.022
# Batch 11, Loss: 0.268
# Batch 21, Loss: 0.231
# Batch 31, Loss: 0.269
# Batch 41, Loss: 0.232
# Batch 51, Loss: 0.210
# Batch 61, Loss: 0.194
# Batch 71, Loss: 0.212
#
# Epoch: 4
# Batch 1, Loss: 0.017
# Batch 11, Loss: 0.203
# Batch 21, Loss: 0.158
# Batch 31, Loss: 0.140
# Batch 41, Loss: 0.119
# Batch 51, Loss: 0.108
# Batch 61, Loss: 0.118
# Batch 71, Loss: 0.106
#
# Epoch: 5
# Batch 1, Loss: 0.010
# Batch 11, Loss: 0.060
# Batch 21, Loss: 0.067
# Batch 31, Loss: 0.060
# Batch 41, Loss: 0.052
# Batch 51, Loss: 0.047
# Batch 61, Loss: 0.037
# Batch 71, Loss: 0.033
#
# Epoch: 6
# Batch 1, Loss: 0.006
# Batch 11, Loss: 0.022
# Batch 21, Loss: 0.019
# Batch 31, Loss: 0.022
# Batch 41, Loss: 0.020
# Batch 51, Loss: 0.018
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.015
#
# Epoch: 7
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.023
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.026
# Batch 71, Loss: 0.015
#
# Epoch: 8
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.015
# Batch 61, Loss: 0.020
# Batch 71, Loss: 0.017
#
# Epoch: 9
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.016
# Batch 51, Loss: 0.015
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.014
#
# Epoch: 10
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.017
# Batch 31, Loss: 0.016
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.016
# Batch 71, Loss: 0.011
#
# Epoch: 11
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.014
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.010
#
# Epoch: 12
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.008
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 14
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.006
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 15
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.006
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.013
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.006
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 19
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.006
# Batch 71, Loss: 0.008
#
# Epoch: 20
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.011
#
# Epoch: 1
# Batch 1, Loss: 0.099
# Batch 11, Loss: 1.861
# Batch 21, Loss: 1.569
# Batch 31, Loss: 1.414
# Batch 41, Loss: 1.141
# Batch 51, Loss: 1.076
# Batch 61, Loss: 0.713
# Batch 71, Loss: 0.586
#
# Epoch: 2
# Batch 1, Loss: 0.062
# Batch 11, Loss: 0.521
# Batch 21, Loss: 0.456
# Batch 31, Loss: 0.329
# Batch 41, Loss: 0.207
# Batch 51, Loss: 0.285
# Batch 61, Loss: 0.213
# Batch 71, Loss: 0.238
#
# Epoch: 3
# Batch 1, Loss: 0.029
# Batch 11, Loss: 0.211
# Batch 21, Loss: 0.185
# Batch 31, Loss: 0.195
# Batch 41, Loss: 0.132
# Batch 51, Loss: 0.203
# Batch 61, Loss: 0.157
# Batch 71, Loss: 0.179
#
# Epoch: 4
# Batch 1, Loss: 0.018
# Batch 11, Loss: 0.154
# Batch 21, Loss: 0.156
# Batch 31, Loss: 0.126
# Batch 41, Loss: 0.126
# Batch 51, Loss: 0.101
# Batch 61, Loss: 0.082
# Batch 71, Loss: 0.074
#
# Epoch: 5
# Batch 1, Loss: 0.006
# Batch 11, Loss: 0.080
# Batch 21, Loss: 0.065
# Batch 31, Loss: 0.060
# Batch 41, Loss: 0.049
# Batch 51, Loss: 0.040
# Batch 61, Loss: 0.046
# Batch 71, Loss: 0.035
#
# Epoch: 6
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.026
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.016
# Batch 41, Loss: 0.016
# Batch 51, Loss: 0.020
# Batch 61, Loss: 0.018
# Batch 71, Loss: 0.012
#
# Epoch: 7
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.017
# Batch 71, Loss: 0.011
#
# Epoch: 8
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.014
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.013
#
# Epoch: 9
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.012
#
# Epoch: 10
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.012
#
# Epoch: 11
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.012
#
# Epoch: 14
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.015
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.010
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.008
#
# Epoch: 16
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.014
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.007
# Batch 21, Loss: 0.015
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.009
#
# Epoch: 18
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.009
#
# Epoch: 19
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.010
#
# Epoch: 20
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.008
#
# Epoch: 1
# Batch 1, Loss: 0.086
# Batch 11, Loss: 0.764
# Batch 21, Loss: 0.801
# Batch 31, Loss: 0.574
# Batch 41, Loss: 0.665
# Batch 51, Loss: 0.427
# Batch 61, Loss: 0.325
# Batch 71, Loss: 0.429
#
# Epoch: 2
# Batch 1, Loss: 0.027
# Batch 11, Loss: 0.369
# Batch 21, Loss: 0.319
# Batch 31, Loss: 0.240
# Batch 41, Loss: 0.242
# Batch 51, Loss: 0.260
# Batch 61, Loss: 0.218
# Batch 71, Loss: 0.219
#
# Epoch: 3
# Batch 1, Loss: 0.017
# Batch 11, Loss: 0.190
# Batch 21, Loss: 0.178
# Batch 31, Loss: 0.207
# Batch 41, Loss: 0.192
# Batch 51, Loss: 0.157
# Batch 61, Loss: 0.150
# Batch 71, Loss: 0.099
#
# Epoch: 4
# Batch 1, Loss: 0.013
# Batch 11, Loss: 0.083
# Batch 21, Loss: 0.087
# Batch 31, Loss: 0.083
# Batch 41, Loss: 0.060
# Batch 51, Loss: 0.060
# Batch 61, Loss: 0.052
# Batch 71, Loss: 0.041
#
# Epoch: 5
# Batch 1, Loss: 0.004
# Batch 11, Loss: 0.036
# Batch 21, Loss: 0.019
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.016
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.013
#
# Epoch: 6
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 7
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.007
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.016
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.008
#
# Epoch: 8
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.005
# Batch 71, Loss: 0.013
#
# Epoch: 9
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.010
#
# Epoch: 10
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 11
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.005
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.011
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.008
#
# Epoch: 13
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.009
#
# Epoch: 14
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.006
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.007
#
# Epoch: 15
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 16
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.007
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.008
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.009
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.005
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.010
#
# Epoch: 19
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.007
# ...
#
# Epoch: 4
# Batch 1, Loss: 0.030
# Batch 11, Loss: 0.119
# Batch 21, Loss: 0.124
# Batch 31, Loss: 0.143
# Batch 41, Loss: 0.116
# Batch 51, Loss: 0.104
# Batch 61, Loss: 0.121
# Batch 71, Loss: 0.092
# Batch 81, Loss: 0.095
#
# Epoch: 5
# Batch 1, Loss: 0.004
# Batch 11, Loss: 0.071
# Batch 21, Loss: 0.057
# Batch 31, Loss: 0.063
# Batch 41, Loss: 0.050
# Batch 51, Loss: 0.029
# Batch 61, Loss: 0.041
# Batch 71, Loss: 0.029
# Batch 81, Loss: 0.027
#
# Epoch: 6
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.025
# Batch 21, Loss: 0.034
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.027
# Batch 61, Loss: 0.022
# Batch 71, Loss: 0.021
# Batch 81, Loss: 0.019
#
# Epoch: 7
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.027
# Batch 31, Loss: 0.023
# Batch 41, Loss: 0.022
# Batch 51, Loss: 0.018
# Batch 61, Loss: 0.021
# Batch 71, Loss: 0.018
# Batch 81, Loss: 0.013
#
# Epoch: 8
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.019
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.020
# Batch 71, Loss: 0.020
# Batch 81, Loss: 0.018
#
# Epoch: 9
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.018
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.016
# Batch 41, Loss: 0.016
# Batch 51, Loss: 0.018
# Batch 61, Loss: 0.016
# Batch 71, Loss: 0.016
# Batch 81, Loss: 0.013
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.018
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.011
# Batch 81, Loss: 0.011
#
# Epoch: 11
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.017
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.018
# Batch 81, Loss: 0.014
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.011
# Batch 81, Loss: 0.011
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.009
# Batch 81, Loss: 0.009
#
# Epoch: 14
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.008
# Batch 81, Loss: 0.013
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.008
# Batch 81, Loss: 0.009
#
# Epoch: 16
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.012
# Batch 81, Loss: 0.014
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.009
# Batch 81, Loss: 0.009
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.011
# Batch 81, Loss: 0.006
#
# Epoch: 19
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.008
# Batch 81, Loss: 0.010
#
# Epoch: 20
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.009
# Batch 81, Loss: 0.010
#
# Epoch: 1
# Batch 1, Loss: 0.485
# Batch 11, Loss: 4.526
# Batch 21, Loss: 4.495
# Batch 31, Loss: 3.893
# Batch 41, Loss: 3.845
# Batch 51, Loss: 3.442
# Batch 61, Loss: 2.953
# Batch 71, Loss: 3.210
# Batch 81, Loss: 2.427
#
# Epoch: 2
# Batch 1, Loss: 0.222
# Batch 11, Loss: 2.683
# Batch 21, Loss: 2.508
# Batch 31, Loss: 2.287
# Batch 41, Loss: 2.120
# Batch 51, Loss: 1.877
# Batch 61, Loss: 1.668
# Batch 71, Loss: 1.449
# Batch 81, Loss: 1.500
#
# Epoch: 3
# Batch 1, Loss: 0.093
# Batch 11, Loss: 1.284
# Batch 21, Loss: 0.910
# Batch 31, Loss: 0.916
# Batch 41, Loss: 0.666
# Batch 51, Loss: 0.765
# Batch 61, Loss: 0.477
# Batch 71, Loss: 0.461
# Batch 81, Loss: 0.489
#
# Epoch: 4
# Batch 1, Loss: 0.043
# Batch 11, Loss: 0.329
# Batch 21, Loss: 0.296
# Batch 31, Loss: 0.278
# Batch 41, Loss: 0.200
# Batch 51, Loss: 0.251
# Batch 61, Loss: 0.178
# Batch 71, Loss: 0.205
# Batch 81, Loss: 0.206
#
# Epoch: 5
# Batch 1, Loss: 0.013
# Batch 11, Loss: 0.173
# Batch 21, Loss: 0.169
# Batch 31, Loss: 0.161
# Batch 41, Loss: 0.159
# Batch 51, Loss: 0.119
# Batch 61, Loss: 0.141
# Batch 71, Loss: 0.139
# Batch 81, Loss: 0.132
#
# Epoch: 6
# Batch 1, Loss: 0.010
# Batch 11, Loss: 0.124
# Batch 21, Loss: 0.084
# Batch 31, Loss: 0.060
# Batch 41, Loss: 0.066
# Batch 51, Loss: 0.054
# Batch 61, Loss: 0.061
# Batch 71, Loss: 0.049
# Batch 81, Loss: 0.028
#
# Epoch: 7
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.033
# Batch 21, Loss: 0.021
# Batch 31, Loss: 0.017
# Batch 41, Loss: 0.018
# Batch 51, Loss: 0.018
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.010
# Batch 81, Loss: 0.016
#
# Epoch: 8
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.015
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.009
# Batch 81, Loss: 0.014
#
# Epoch: 9
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.016
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.018
# Batch 71, Loss: 0.008
# Batch 81, Loss: 0.009
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.015
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.016
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.010
# Batch 81, Loss: 0.009
#
# Epoch: 11
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.009
# Batch 81, Loss: 0.012
#
# Epoch: 12
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.009
# Batch 81, Loss: 0.011
#
# Epoch: 13
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.012
# Batch 81, Loss: 0.010
#
# Epoch: 14
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.010
# Batch 81, Loss: 0.010
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.016
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.007
# Batch 81, Loss: 0.009
#
# Epoch: 16
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.006
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.011
# Batch 81, Loss: 0.009
#
# Epoch: 17
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.012
# Batch 81, Loss: 0.010
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.006
# Batch 81, Loss: 0.010
#
# Epoch: 19
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.013
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.007
# Batch 81, Loss: 0.010
#
# Epoch: 20
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.005
# Batch 81, Loss: 0.010
#
# Epoch: 1
# Batch 1, Loss: 0.032
# Batch 11, Loss: 1.219
# Batch 21, Loss: 0.998
# Batch 31, Loss: 0.888
# Batch 41, Loss: 0.707
# Batch 51, Loss: 0.802
# Batch 61, Loss: 0.730
# Batch 71, Loss: 0.475
# Batch 81, Loss: 0.557
#
# Epoch: 2
# Batch 1, Loss: 0.068
# Batch 11, Loss: 0.447
# Batch 21, Loss: 0.349
# Batch 31, Loss: 0.380
# Batch 41, Loss: 0.324
# Batch 51, Loss: 0.311
# Batch 61, Loss: 0.356
# Batch 71, Loss: 0.380
# Batch 81, Loss: 0.331
#
# Epoch: 3
# Batch 1, Loss: 0.027
# Batch 11, Loss: 0.340
# Batch 21, Loss: 0.253
# Batch 31, Loss: 0.304
# Batch 41, Loss: 0.281
# Batch 51, Loss: 0.259
# Batch 61, Loss: 0.296
# Batch 71, Loss: 0.269
# Batch 81, Loss: 0.219
#
# Epoch: 4
# Batch 1, Loss: 0.023
# Batch 11, Loss: 0.302
# Batch 21, Loss: 0.245
# Batch 31, Loss: 0.263
# Batch 41, Loss: 0.223
# Batch 51, Loss: 0.193
# Batch 61, Loss: 0.172
# Batch 71, Loss: 0.186
# Batch 81, Loss: 0.167
#
# Epoch: 5
# Batch 1, Loss: 0.023
# Batch 11, Loss: 0.174
# Batch 21, Loss: 0.167
# Batch 31, Loss: 0.153
# Batch 41, Loss: 0.158
# Batch 51, Loss: 0.148
# Batch 61, Loss: 0.103
# Batch 71, Loss: 0.088
# Batch 81, Loss: 0.126
#
# Epoch: 6
# Batch 1, Loss: 0.009
# Batch 11, Loss: 0.119
# Batch 21, Loss: 0.075
# Batch 31, Loss: 0.089
# Batch 41, Loss: 0.057
# Batch 51, Loss: 0.050
# Batch 61, Loss: 0.039
# Batch 71, Loss: 0.047
# Batch 81, Loss: 0.039
#
# Epoch: 7
# Batch 1, Loss: 0.004
# Batch 11, Loss: 0.044
# Batch 21, Loss: 0.032
# Batch 31, Loss: 0.030
# Batch 41, Loss: 0.017
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.018
# Batch 81, Loss: 0.012
#
# Epoch: 8
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.018
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.014
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.015
# Batch 71, Loss: 0.014
# Batch 81, Loss: 0.018
#
# Epoch: 9
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.015
# Batch 61, Loss: 0.019
# Batch 71, Loss: 0.013
# Batch 81, Loss: 0.016
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.007
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.019
# Batch 71, Loss: 0.008
# Batch 81, Loss: 0.016
#
# Epoch: 11
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.016
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.006
# Batch 61, Loss: 0.014
# Batch 71, Loss: 0.010
# Batch 81, Loss: 0.008
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.011
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.008
# Batch 81, Loss: 0.010
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.008
# Batch 81, Loss: 0.014
#
# Epoch: 14
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.010
# Batch 81, Loss: 0.010
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.016
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.005
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.009
# Batch 81, Loss: 0.011
#
# Epoch: 16
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.013
# Batch 81, Loss: 0.010
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.007
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.013
# Batch 81, Loss: 0.007
#
# Epoch: 18
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.006
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.010
# Batch 81, Loss: 0.012
#
# Epoch: 19
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.014
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.008
# Batch 81, Loss: 0.009
#
# Epoch: 20
# Batch 1, Loss: 0.002
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.007
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.007
# Batch 71, Loss: 0.015
# Batch 81, Loss: 0.007
#
# Epoch: 1
# Batch 1, Loss: 0.386
# Batch 11, Loss: 3.906
# Batch 21, Loss: 3.747
# Batch 31, Loss: 3.089
# Batch 41, Loss: 2.950
# Batch 51, Loss: 2.801
# Batch 61, Loss: 2.332
# Batch 71, Loss: 2.330
# Batch 81, Loss: 2.127
#
# Epoch: 2
# Batch 1, Loss: 0.114
# Batch 11, Loss: 1.772
# Batch 21, Loss: 1.550
# Batch 31, Loss: 1.285
# Batch 41, Loss: 1.138
# Batch 51, Loss: 0.834
# Batch 61, Loss: 0.701
# Batch 71, Loss: 0.463
# Batch 81, Loss: 0.334
#
# Epoch: 3
# Batch 1, Loss: 0.054
# Batch 11, Loss: 0.296
# Batch 21, Loss: 0.262
# Batch 31, Loss: 0.144
# Batch 41, Loss: 0.138
# Batch 51, Loss: 0.179
# Batch 61, Loss: 0.145
# Batch 71, Loss: 0.161
# Batch 81, Loss: 0.149
#
# Epoch: 4
# Batch 1, Loss: 0.013
# Batch 11, Loss: 0.098
# Batch 21, Loss: 0.100
# Batch 31, Loss: 0.115
# Batch 41, Loss: 0.081
# Batch 51, Loss: 0.088
# Batch 61, Loss: 0.095
# Batch 71, Loss: 0.072
# Batch 81, Loss: 0.074
#
# Epoch: 5
# Batch 1, Loss: 0.004
# Batch 11, Loss: 0.039
# Batch 21, Loss: 0.051
# Batch 31, Loss: 0.036
# Batch 41, Loss: 0.029
# Batch 51, Loss: 0.019
# Batch 61, Loss: 0.031
# Batch 71, Loss: 0.020
# Batch 81, Loss: 0.020
#
# Epoch: 6
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.015
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.014
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.012
# Batch 61, Loss: 0.013
# Batch 71, Loss: 0.014
# Batch 81, Loss: 0.013
#
# Epoch: 7
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.011
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.014
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.013
# Batch 81, Loss: 0.009
#
# Epoch: 8
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.011
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.012
# Batch 71, Loss: 0.009
# Batch 81, Loss: 0.010
#
# Epoch: 9
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.012
# Batch 21, Loss: 0.012
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.012
# Batch 81, Loss: 0.011
#
# Epoch: 10
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.011
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.010
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.013
# Batch 81, Loss: 0.010
#
# Epoch: 11
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.007
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.007
# Batch 81, Loss: 0.012
#
# Epoch: 12
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.013
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.008
# Batch 71, Loss: 0.010
# Batch 81, Loss: 0.008
#
# Epoch: 13
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.010
# Batch 31, Loss: 0.009
# Batch 41, Loss: 0.008
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.007
# Batch 81, Loss: 0.013
#
# Epoch: 14
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.007
# Batch 21, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.012
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.010
# Batch 81, Loss: 0.011
#
# Epoch: 15
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.006
# Batch 21, Loss: 0.009
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.008
# Batch 81, Loss: 0.010
#
# Epoch: 16
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.006
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.012
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.010
# Batch 61, Loss: 0.010
# Batch 71, Loss: 0.013
# Batch 81, Loss: 0.008
#
# Epoch: 17
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.010
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.010
# Batch 41, Loss: 0.013
# Batch 51, Loss: 0.009
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.006
# Batch 81, Loss: 0.007
#
# Epoch: 18
# Batch 1, Loss: 0.000
# Batch 11, Loss: 0.013
# Batch 21, Loss: 0.006
# Batch 31, Loss: 0.008
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.009
# Batch 81, Loss: 0.008
#
# Epoch: 19
# Batch 1, Loss: 0.001
# Batch 11, Loss: 0.008
# Batch 21, Loss: 0.007
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.011
# Batch 51, Loss: 0.013
# Batch 61, Loss: 0.009
# Batch 71, Loss: 0.014
# Batch 81, Loss: 0.005
#
# Epoch: 20
# Batch 1, Loss: 0.003
# Batch 11, Loss: 0.009
# Batch 21, Loss: 0.008
# Batch 31, Loss: 0.007
# Batch 41, Loss: 0.009
# Batch 51, Loss: 0.008
# Batch 61, Loss: 0.011
# Batch 71, Loss: 0.008
# Batch 81, Loss: 0.011

# %%
my_df = df_fw_list[0].reset_index()


fig = go.Figure()

actual_scat = go.Scatter(x=my_df['ds'][LSTM_loop_back:], y=my_df['y'][LSTM_loop_back:], mode='lines', name="Actual Price y", line=dict(color='red'))

# get predict
predicted = get_predict(model=list_LSTM_model[0],X=X_train_list[0], scaler=scaler_LSTM_list[0])
# plot it
predicted_scat = go.Scatter(x=my_df['ds'][LSTM_loop_back:], y=predicted, mode='lines', name="ARIMA-LSTM Predict Price yhat", line=dict(color='blue'))

prop_predicted_scat = go.Scatter(x=my_df['ds'][LSTM_loop_back:], y=df_predict_list[0]['yhat'][LSTM_loop_back:], mode='lines', name=f"ARIMA{best_p,1,best_q}", line=dict(color='green'))


fig.add_trace(actual_scat)
fig.add_trace(prop_predicted_scat)
fig.add_trace(predicted_scat)
fig.update_layout(title_text=f'{stock_target} a random horizon in samples predict')

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(my_df['y'][LSTM_loop_back:], df_predict_list[0]['yhat'][LSTM_loop_back:])

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print(f"ARIMA{best_p,1,best_q} Root Mean Squared Error (RMSE): {rmse}")
print(f"Correlation: {np.corrcoef(my_df['y'][LSTM_loop_back:],  df_predict_list[0]['yhat'][LSTM_loop_back:])[0,1]}")
# Out:
# ARIMA(9, 1, 9) Root Mean Squared Error (RMSE): 896.8023457818331
# Correlation: 0.9885624697421087

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(my_df['y'][LSTM_loop_back:], predicted)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print(f"ARIMA-LSTM Root Mean Squared Error (RMSE): {rmse}")

print(f"Correlation: {np.corrcoef(my_df['y'][LSTM_loop_back:], predicted)[0,1]}")
# Out:
# ARIMA-LSTM Root Mean Squared Error (RMSE): 906.4100377274584
# Correlation: 0.988309044506041

# %% [markdown]
# #### Moving Forward Predict for ARIMA-LSTM

# %%
def create_X_LSTM(X, scaler, number_features):
    X = np.atleast_2d(np.array(X))
    yX = np.atleast_2d(np.append(np.zeros((X.shape[0], 1)),X))
    yX_scaler = scaler.transform(yX)
    X_3D = yX_scaler[:,1:].reshape((-1, 1, number_features))
    return X_3D


def create_X_predict_next_day(arima_model, shifted_df_LSTM):
    forecast = arima_model.forecast(steps=1)
    # get the current yhat -> yhat(t - LSTM_loop_back -1) total is LSTM_loop_back
    lag_yhat = shifted_df_LSTM.iloc[-1:,1:1+LSTM_loop_back]
    # skip oldest yhat cols and get from latest reisd to oldest resid - 1
    lag_resid = shifted_df_LSTM.iloc[-1:, 1+ LSTM_loop_back + 1: -1]
    current_reisd = (shifted_df_LSTM[-1:]['y'] - shifted_df_LSTM[-1:]['yhat'])
    next_yhat = forecast
    #return create_X_LSTM(np.append(lag_X,latest_X,axis=0))
    merge_X = np.concatenate((np.array(next_yhat).flatten(),np.array(lag_yhat).flatten(),np.array(current_reisd).flatten(),np.array(lag_resid).flatten()),axis=0)
    return merge_X

def get_predict_next_day(LSTM_model,scaler,arima_model,shifted_df_LSTM):
    X_predict_next_day = create_X_predict_next_day(arima_model,shifted_df_LSTM) 
    X_scaler = create_X_LSTM(X_predict_next_day, scaler, LSTM_loop_back + 1 + LSTM_resid_loop_back)
    y_predict_next_day = get_predict(LSTM_model, X_scaler, scaler)[-1:]
    return y_predict_next_day[0]

# %%
def get_list_next_day_predict_test_range():
    next_days = []
    for LSTM_model, scaler, arima_model, shifted_df_LSTM  in zip(list_LSTM_model, scaler_LSTM_list, list_model, shifted_df_LSTM_list):
      next_day_predict = get_predict_next_day(model, scaler, arima_model, shifted_df_LSTM)
      next_days.append(next_day_predict)
    return np.array(next_days).reshape(len(next_days))



def create_evalute_table():
    next_days = get_list_next_day_predict_test_range()
    df = get_list_next_day_actual_test_range()
    df['predict'] = pd.Series(next_days)
    df[['ds','y','yhat']] = df[['time','close','predict']]
    df = df[['ds','y','yhat']]
    df['ds'] = pd.to_datetime(df['ds'])
    return df

# %%
get_list_next_day_actual_test_range()
# Out:
#           time   open   high    low  close  volume ticker
# 0   2023-08-22  24000  24200  22500  23700  565100    VGI
# 1   2023-08-23  23500  24000  23500  23500  173900    VGI
# 2   2023-08-24  23400  24000  23400  24000  261600    VGI
# 3   2023-08-25  27000  27000  23600  24200  551100    VGI
# 4   2023-08-28  24600  24800  24000  24700  344200    VGI
# ..         ...    ...    ...    ...    ...     ...    ...
# 83  2023-12-20  25000  25300  25000  25200  348300    VGI
# 84  2023-12-21  25200  25300  25000  25100  178000    VGI
# 85  2023-12-22  25300  25700  25300  25500  425400    VGI
# 86  2023-12-25  25500  25900  25500  25800  411000    VGI
# 87  2023-12-26  25800  26200  25700  25900  535100    VGI
#
# [88 rows x 7 columns]

# %%
df_eval = create_evalute_table()
df_eval['y_change'] = df_eval['y'].diff()
df_eval['yhat_change'] = df_eval['yhat'].diff()
df_eval['y*yhat_chage'] = df_eval['y_change'] * df_eval['yhat_change']

# %%
df_eval
# Out:
#            ds      y          yhat  y_change  yhat_change   y*yhat_chage
# 0  2023-08-22  23700  24008.628279       NaN          NaN            NaN
# 1  2023-08-23  23500  23776.509464    -200.0  -232.118815   46423.763037
# 2  2023-08-24  24000  23400.233537     500.0  -376.275927 -188137.963414
# 3  2023-08-25  24200  23908.428997     200.0   508.195460  101639.091969
# 4  2023-08-28  24700  24020.124227     500.0   111.695230   55847.615004
# ..        ...    ...           ...       ...          ...            ...
# 83 2023-12-20  25200  25020.724535     200.0   469.669104   93933.820724
# 84 2023-12-21  25100  25236.636102    -100.0   215.911567  -21591.156721
# 85 2023-12-22  25500  24934.715480     400.0  -301.920623 -120768.249035
# 86 2023-12-25  25800  25446.267724     300.0   511.552244  153465.673327
# 87 2023-12-26  25900  25650.811195     100.0   204.543471   20454.347134
#
# [88 rows x 6 columns]

# %%
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(df_eval['y'], df_eval['yhat']))
print(f"Root Mean Squared Error (RMSE): {rmse}")

# Calculate correlation coefficient
correlation = df_eval['y'].corr(df_eval['yhat'])
print(f"Correlation Coefficient: {correlation}")

truth = []
for y_hat_change, y_change in zip(df_eval['yhat'].diff().dropna(),df_eval['y'].diff().dropna()):
    truth.append(1 if y_hat_change * y_change > 0 else 0)


print(f"Direction correction ratio: {np.sum(truth)/len(truth) * 100}")

r2 = r2_score(df_eval['y'], df_eval['yhat'])
print(f"R-squared (R²): {r2}")
# Out:
# Root Mean Squared Error (RMSE): 688.4520124095163
# Correlation Coefficient: 0.9034281951395763
# Direction correction ratio: 49.42528735632184
# R-squared (R²): 0.7999096120986804

# %%
df_mtr = pd.read_csv('./output/metrics-VGI.csv')
# remove old record
df_mtr = df_mtr[~(df_mtr['model'] == 'ARIMA-LSTM')]

df_mtr = pd.concat([df_mtr,
                    pd.DataFrame({
                     'model': ['ARIMA-LSTM'],
                     'rmse': [rmse],
                     'correlation': [correlation],
                     'r-squared': [r2] })], axis=0)
df_mtr.to_csv('./output/metrics-VGI.csv',index=False)

# %%
# Plotting with Plotly
fig = go.Figure()

# Plot yhat as a line
fig.add_trace(go.Scatter(x=df_eval['ds'], y=df_eval['yhat'], mode='lines+markers', name='yhat', line=dict(color='blue')))

# Plot y as points
fig.add_trace(go.Scatter(x=df_eval['ds'], y=df_eval['y'], mode='lines+markers', name='y', marker=dict(color='red', size=8)))

# Set layout
fig.update_layout(title=f'ARIMA{best_p,1,best_q}-LSTM {stock_target} moving forward train and predict the next day with ARIMA-LSTM',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  showlegend=True)

# Show the plot
fig.show()
